# %% [markdown]
# ## Example - Fit TransE from CSVs in disk
# * put the training and validation CSVs in seprate folders like:
# └──train_data
#         ├───train_1.csv
#         ├───train_2.csv
# └──valid_data
#         ├───valid_1.csv
#         ├───valid_2.csv
# * each csv file store 3 columns with (h,r,t) repectively (with no header).
# * you can split the data into multiple CSVs.

# %%
from KGE.TransE import TransE

# %%
model = TransE(embedding_size = 100, negative_ratio = 10, corrupt_side = 'h+t', margin = 0.5, norm = 2, batch_corrupt = True)

# %%
model.fit(train_X = "data/fb15k_237_train", val_X = "data/fb15k_237_valid", epochs = 20, learning_rate = 0.001, batch_count = 100,
          early_stopping = None, log_path = "tensorboard/TransE_logs")
# Out:
# INFO:root:[2020-09-09 18:55:57.062945] Preprocessing training triplet...
# INFO:root:[2020-09-09 18:55:57.677173] Initialize Embeddings...
# INFO:root:[2020-09-09 18:55:57.684164] Start Training...
# epoch: 19, train loss: 0.024528, valid loss: 0.037821: 100%|██████████| 20/20 [05:16<00:00, 15.82s/it]

# %% [markdown]
# ### Get Entities & Relations Embeddings

# %%
model.get_embeddings(['/m/027rn', '/m/06cx9'], embedding_type = 'entity')
# Out:
# array([[-0.04433256, -0.17493737, -0.15591688,  0.04056852, -0.09089171,
#         -0.07912163,  0.03474689,  0.15898398,  0.150213  , -0.11283677,
#          0.03728622,  0.10838893,  0.1017431 , -0.026868  ,  0.14073792,
#         -0.13027509,  0.03504661,  0.10883214, -0.13251556, -0.18425453,
#         -0.09046879, -0.04345833, -0.02855208,  0.14018781,  0.22457458,
#          0.05537203, -0.03128373,  0.10077996,  0.03728304, -0.1406233 ,
#         -0.08404887, -0.03968583,  0.12828548,  0.0339542 , -0.09423982,
#          0.16179712,  0.07182038, -0.08429069, -0.04872237,  0.05074064,
#         -0.08736536, -0.06665482,  0.15172175,  0.0320746 , -0.11772228,
#          0.1401052 ,  0.09355219,  0.17303786, -0.00050522,  0.210382  ,
#          0.04339588, -0.14609516, -0.09212832,  0.0056595 ,  0.2545179 ,
#          0.07527926, -0.18581122,  0.19840293,  0.15205744, -0.07622391,
#         -0.13836691,  0.11174433, -0.03868292, -0.03264686,  0.08910865,
#          0.07501779, -0.07740796, -0.16403764, -0.01066521,  0.11505464,
#          0.1079168 , -0.06726338, -0.23678133, -0.04221377,  0.15700501,
#         -0.14393502, -0.13230762,  0.08509633, -0.10035963, -0.0736377 ,
#          0.08377673,  0.08046769,  0.0889875 , -0.17748694, -0.01472838,
#         -0.04770932, -0.10520159,  0.06737821,  0.17964941,  0.13443653,
#          0.07936729, -0.00950239,  0.07869896,  0.15924205, -0.0851485 ,
#          0.00234742, -0.14818321, -0.06125845,  0.07738646, -0.10269396],
#        [ 0.12111447,  0.06889699,  0.08806024,  0.1031756 ,  0.19364695,
#          0.04679427,  0.12042192,  0.13204777,  0.02087151,  0.05576627,
#         -0.06366587,  0.13114743, -0.07461717,  0.08246211,  0.13113257,
#         -0.14563407,  0.06325996, -0.08611692,  0.07966763,  0.08085464,
#          0.08872577,  0.11143798, -0.12557228,  0.19049554, -0.05350576,
#          0.09334722,  0.12117901,  0.11488073,  0.1341311 ,  0.118113  ,
#         -0.04090883, -0.09381867,  0.0331958 , -0.09835237, -0.10936741,
#         -0.09630159, -0.12614621, -0.15318595, -0.13122165,  0.07582121,
#         -0.11773185,  0.16076045, -0.10538419, -0.10516957,  0.10737562,
#          0.17545997,  0.10082889,  0.13044053, -0.04363943,  0.22023888,
#         -0.07987543,  0.07235816, -0.13264407,  0.10316232, -0.06416647,
#          0.12243547,  0.10221066,  0.13567613, -0.11593807,  0.11040176,
#         -0.03385412,  0.1922947 , -0.07244527, -0.14230207, -0.10832378,
#         -0.10713336,  0.14135513, -0.11932851, -0.11323111, -0.10994011,
#          0.06968185,  0.13784882,  0.07288782, -0.15024608,  0.06296607,
#          0.05423989,  0.0783787 , -0.11100507,  0.05119821,  0.12567447,
#         -0.13099277,  0.08254682,  0.14225253,  0.10309707,  0.03678295,
#          0.1394486 , -0.11957196,  0.16757038,  0.14365916, -0.07980014,
#         -0.06572753, -0.11780932,  0.15917665, -0.07343747,  0.01723834,
#          0.08988824, -0.13244745, -0.14859188,  0.20298749,  0.06644233]],
#       dtype=float32)

# %%
model.get_embeddings(['/location/country/form_of_government'], embedding_type = 'relation')
# Out:
# array([[ 0.17536214,  0.11498808,  0.26552436,  0.15539597,  0.17944202,
#         -0.01281165,  0.18916929,  0.0061124 , -0.10598401,  0.18266352,
#         -0.09038032, -0.02138694, -0.20029911,  0.17160851, -0.0064995 ,
#         -0.00677435,  0.06493562, -0.17669371,  0.25101805,  0.27390635,
#          0.17558819,  0.2349753 ,  0.01315945,  0.02189637, -0.32059684,
#          0.05932235,  0.16877875,  0.01193699,  0.06152887,  0.20136909,
#          0.08118254, -0.04933951, -0.11871526, -0.16707268, -0.03127211,
#         -0.23704672, -0.13372345,  0.01986436, -0.09853824,  0.01330855,
#         -0.11188354,  0.17154299, -0.19063637, -0.21155499,  0.15446085,
#         -0.03097828, -0.01398807,  0.00800423, -0.1263265 , -0.04188505,
#         -0.16649154,  0.26864064,  0.01338554,  0.19668919, -0.26765814,
#         -0.02364636,  0.31473708,  0.01348936, -0.23726721,  0.24971965,
#          0.0721427 , -0.04442139, -0.01122312, -0.18770291, -0.16007502,
#         -0.15705977,  0.18173578, -0.03129192, -0.05025481, -0.2353949 ,
#         -0.02952336,  0.07337113,  0.2560998 , -0.14424782, -0.06412935,
#          0.26535013,  0.1775742 , -0.24767353,  0.21425417,  0.28317544,
#         -0.11899611,  0.07052469, -0.01304962,  0.16151087,  0.11975521,
#          0.18746369, -0.02586193,  0.01670297, -0.02498752, -0.19370168,
#         -0.15959309,  0.00202258, -0.00276691, -0.2348058 ,  0.05563458,
#         -0.01375341,  0.01677981,  0.01920883, -0.00857773,  0.19634086]],
#       dtype=float32)

# %% [markdown]
# ### Get All Entities & Relations Embeddings

# %%
# entities embeddings
model.ent_emb.numpy()
# Out:
# array([[ 0.14059348,  0.08235925, -0.12740146, ...,  0.00669367,
#         -0.07217453,  0.12388209],
#        [ 0.02632413,  0.09181372, -0.0963528 , ...,  0.03060952,
#         -0.12859109,  0.11586931],
#        [ 0.00043591, -0.1603149 , -0.07471798, ...,  0.06274986,
#         -0.06321405, -0.06286403],
#        ...,
#        [-0.20838852,  0.00821889,  0.03450869, ..., -0.03865098,
#         -0.18429   , -0.03541154],
#        [ 0.11678603, -0.05030166, -0.14026417, ..., -0.13259949,
#          0.02838923,  0.15154475],
#        [-0.03415262,  0.06427687,  0.1156728 , ...,  0.10849107,
#          0.00247433, -0.0780201 ]], dtype=float32)

# %%
# relations embeddings
model.rel_emb.numpy()
# Out:
# array([[ 0.22122599, -0.16368595, -0.19892941, ...,  0.1593274 ,
#          0.1402985 ,  0.04958722],
#        [ 0.09419548,  0.19979738, -0.19789302, ..., -0.0238177 ,
#          0.18317473,  0.27955082],
#        [-0.1962291 , -0.19018427,  0.11395627, ..., -0.22741817,
#          0.14410055,  0.13695306],
#        ...,
#        [-0.12117118, -0.11929075,  0.10740736, ...,  0.00787964,
#          0.03663487, -0.02768844],
#        [ 0.08228766, -0.0214036 , -0.19921705, ..., -0.03056948,
#          0.09556547,  0.16867003],
#        [ 0.13226622, -0.02123455, -0.28177258, ...,  0.04508905,
#         -0.13101278,  0.27782527]], dtype=float32)

# %% [markdown]
# ### Get Entities & Relations Dictionary

# %%
model.dict_ent2id
# Out:
# {'/m/015ynm': 0,
#  '/m/0dp7wt': 1,
#  '/m/01z8f0': 2,
#  '/m/0m491': 3,
#  '/m/012201': 4,
#  '/m/0906w9': 5,
#  '/m/07_pf': 6,
#  '/m/0g0vx': 7,
#  '/m/023mdt': 8,
#  '/m/0kjrx': 9,
#  '/m/030qb3t': 10,
#  '/m/0138mv': 11,
#  '/m/03v0t': 12,
#  '/m/06mr6': 13,
#  '/m/07ldhs': 14,
#  '/m/01vxqyl': 15,
#  '/m/0gwgn1k': 16,
#  '/m/01jqr_5': 17,
#  '/m/05j0wc': 18,
#  '/m/06f32': 19,
#  '/m/046n4q': 20,
#  '/m/0882r_': 21,
#  '/m/0gq6s3': 22,
#  '/m/0bvzp': 23,
#  '/m/01nfys': 24,
#  '/m/0fj9f': 25,
#  '/m/02psgq': 26,
#  '/m/03dhbp': 27,
#  '/m/018gqj': 28,
#  '/m/016vqk': 29,
#  '/m/03zw80': 30,
#  '/m/05btx9': 31,
#  '/m/0fw9n7': 32,
#  '/m/051n13': 33,
#  '/m/03z9585': 34,
#  '/m/01817f': 35,
#  '/m/01r4k': 36,
#  '/m/044l47': 37,
#  '/m/01wrcxr': 38,
#  '/m/02z3cm0': 39,
#  '/m/02lhm2': 40,
#  '/m/0l4vc': 41,
#  '/m/07sc6nw': 42,
#  '/m/01k2yr': 43,
#  '/m/05y0cr': 44,
#  '/m/01dhmw': 45,
#  '/m/034np8': 46,
#  '/m/0dmy0': 47,
#  '/m/0g7pm': 48,
#  '/m/019mdt': 49,
#  '/m/023b97': 50,
#  '/m/0g5ff': 51,
#  '/m/02kxbx3': 52,
#  '/m/0443xn': 53,
#  '/m/09qgm': 54,
#  '/m/01kgxf': 55,
#  '/m/0mwh1': 56,
#  '/m/0l9k1': 57,
#  '/m/047sxrj': 58,
#  '/m/03bdv': 59,
#  '/m/046b0s': 60,
#  '/m/02w7gg': 61,
#  '/m/0gj8nq2': 62,
#  '/m/018q7': 63,
#  '/m/09cdxn': 64,
#  '/m/015y2q': 65,
#  '/m/098s1': 66,
#  '/m/02yv_b': 67,
#  '/m/029skd': 68,
#  '/m/01n8_g': 69,
#  '/m/01nx_8': 70,
#  '/m/01qkqwg': 71,
#  '/m/01y8cr': 72,
#  '/m/035qlx': 73,
#  '/m/03b0q4': 74,
#  '/m/0cw3yd': 75,
#  '/m/029sk': 76,
#  '/m/01dzq6': 77,
#  '/m/0l8z1': 78,
#  '/m/01bbwp': 79,
#  '/m/01bj6y': 80,
#  '/m/0dbc1s': 81,
#  '/m/01516r': 82,
#  '/m/045gzq': 83,
#  '/m/0466k4': 84,
#  '/m/0c58k': 85,
#  '/m/016gb5': 86,
#  '/m/0bx_f_t': 87,
#  '/m/013c6x': 88,
#  '/m/0dc_v': 89,
#  '/m/0124ld': 90,
#  '/m/045m1_': 91,
#  '/m/030h95': 92,
#  '/m/0c422z4': 93,
#  '/m/087v17': 94,
#  '/m/02bbyw': 95,
#  '/m/02j8z': 96,
#  '/m/0m5s5': 97,
#  '/m/02x08c': 98,
#  '/m/01d1yr': 99,
#  '/m/01jv_6': 100,
#  '/m/0k4f3': 101,
#  '/m/023kzp': 102,
#  '/m/0qmjd': 103,
#  '/m/04wvhz': 104,
#  '/m/05v38p': 105,
#  '/m/025n3p': 106,
#  '/m/0537y_': 107,
#  '/m/0jw67': 108,
#  '/m/01f7v_': 109,
#  '/m/01v3rb': 110,
#  '/m/02rn00y': 111,
#  '/m/02lyr4': 112,
#  '/m/02gvwz': 113,
#  '/m/0k4y6': 114,
#  '/m/07wlf': 115,
#  '/m/02h758': 116,
#  '/m/0639bg': 117,
#  '/m/0dlw0': 118,
#  '/m/07gghl': 119,
#  '/m/07f7jp': 120,
#  '/m/01pdgp': 121,
#  '/m/03kts': 122,
#  '/m/0n5_g': 123,
#  '/m/0515_6': 124,
#  '/m/01314k': 125,
#  '/m/0bpm4yw': 126,
#  '/m/04pqqb': 127,
#  '/m/085ccd': 128,
#  '/m/038c0q': 129,
#  '/m/03q0r1': 130,
#  '/m/02gx2x': 131,
#  '/m/034g2b': 132,
#  '/m/01kc4s': 133,
#  '/m/06b19': 134,
#  '/m/060ppp': 135,
#  '/m/0f13b': 136,
#  '/m/02qsfzv': 137,
#  '/m/0h3mrc': 138,
#  '/m/021npv': 139,
#  '/m/01x53m': 140,
#  '/m/0cqt90': 141,
#  '/m/0f1nl': 142,
#  '/m/0sngf': 143,
#  '/m/0ml25': 144,
#  '/m/0ckhc': 145,
#  '/m/0c41qv': 146,
#  '/m/032f6': 147,
#  '/m/040p_q': 148,
#  '/m/01w4c9': 149,
#  '/m/08k1lz': 150,
#  '/m/025y67': 151,
#  '/m/0gzh': 152,
#  '/m/01j851': 153,
#  '/m/0b0nq2': 154,
#  '/m/03gyp30': 155,
#  '/m/04v09': 156,
#  '/m/01hnp': 157,
#  '/m/0ch280': 158,
#  '/m/03fmfs': 159,
#  '/m/0ys4f': 160,
#  '/m/0c00zd0': 161,
#  '/m/02630g': 162,
#  '/m/0g96wd': 163,
#  '/m/01qhm_': 164,
#  '/m/03h_f4': 165,
#  '/m/02d6n_': 166,
#  '/m/027pfb2': 167,
#  '/m/01vd7hn': 168,
#  '/m/0cymln': 169,
#  '/m/0k2h6': 170,
#  '/m/01nf9x': 171,
#  '/m/043vc': 172,
#  '/m/03t5n3': 173,
#  '/m/01x15dc': 174,
#  '/m/0tlq9': 175,
#  '/m/03hxsv': 176,
#  '/m/017c87': 177,
#  '/m/04h4c9': 178,
#  '/m/030p35': 179,
#  '/m/02f8lw': 180,
#  '/m/0q8sw': 181,
#  '/m/05d49': 182,
#  '/m/02r6mf': 183,
#  '/m/0fz0c2': 184,
#  '/m/02f8zw': 185,
#  '/m/05jx2d': 186,
#  '/m/03gj2': 187,
#  '/m/02g5q1': 188,
#  '/m/014vk4': 189,
#  '/m/02k76g': 190,
#  '/m/013b2h': 191,
#  '/m/026fd': 192,
#  '/m/0kpzy': 193,
#  '/m/04b5l3': 194,
#  '/m/02cqny': 195,
#  '/m/02k54': 196,
#  '/m/09p7fh': 197,
#  '/m/02f77y': 198,
#  '/m/01lly5': 199,
#  '/m/05lb87': 200,
#  '/m/0h8d': 201,
#  '/m/02gt5s': 202,
#  '/m/02681vq': 203,
#  '/m/05m_jsg': 204,
#  '/m/0dr7s': 205,
#  '/m/080lkt7': 206,
#  '/m/02qssrm': 207,
#  '/m/01f9zw': 208,
#  '/m/042v2': 209,
#  '/m/0hnlx': 210,
#  '/m/0gr36': 211,
#  '/m/0gw0': 212,
#  '/m/04bnx': 213,
#  '/m/06rrzn': 214,
#  '/m/0b6k40': 215,
#  '/m/09s02': 216,
#  '/m/01ly8d': 217,
#  '/m/013719': 218,
#  '/m/070c93': 219,
#  '/m/01gqg3': 220,
#  '/m/0gqwc': 221,
#  '/m/0rrhp': 222,
#  '/m/019cr': 223,
#  '/m/0257yf': 224,
#  '/m/0195pd': 225,
#  '/m/0mskq': 226,
#  '/m/02f71y': 227,
#  '/m/057xs89': 228,
#  '/m/02s2lg': 229,
#  '/m/023zl': 230,
#  '/m/043gj': 231,
#  '/m/02nygk': 232,
#  '/m/0bl1_': 233,
#  '/m/0dxmyh': 234,
#  '/m/0r1jr': 235,
#  '/m/023s8': 236,
#  '/m/018dh3': 237,
#  '/m/0bk25': 238,
#  '/m/0flw6': 239,
#  '/m/04zw9hs': 240,
#  '/m/0513yzt': 241,
#  '/m/0436kgz': 242,
#  '/m/0cv72h': 243,
#  '/m/0c01c': 244,
#  '/m/0b005': 245,
#  '/m/0_816': 246,
#  '/m/04pry': 247,
#  '/m/0nj0m': 248,
#  '/m/0k5p1': 249,
#  '/m/02q3n9c': 250,
#  '/m/0tc7': 251,
#  '/m/02tqm5': 252,
#  '/m/059x0w': 253,
#  '/m/057n_g': 254,
#  '/m/03q3x5': 255,
#  '/m/02dlfh': 256,
#  '/m/038_l': 257,
#  '/m/03y5ky': 258,
#  '/m/01skqzw': 259,
#  '/m/0njlp': 260,
#  '/m/0hvjr': 261,
#  '/m/0jnrk': 262,
#  '/m/06cmp': 263,
#  '/m/0b_yz': 264,
#  '/m/0m32_': 265,
#  '/m/03f0324': 266,
#  '/m/0bdxs5': 267,
#  '/m/02kc4sf': 268,
#  '/m/04jn6y7': 269,
#  '/m/0lh0c': 270,
#  '/m/01ym8l': 271,
#  '/m/02d44q': 272,
#  '/m/024_41': 273,
#  '/m/03ryzs': 274,
#  '/m/01q2sk': 275,
#  '/m/0ncj8': 276,
#  '/m/03zg2x': 277,
#  '/m/01tmtg': 278,
#  '/m/05wkw': 279,
#  '/m/050llt': 280,
#  '/m/03ncb2': 281,
#  '/m/01vw917': 282,
#  '/m/01dpdh': 283,
#  '/m/01g5v': 284,
#  '/m/0168dy': 285,
#  '/m/0b275x': 286,
#  '/m/04fv0k': 287,
#  '/m/03d96s': 288,
#  '/m/0105y2': 289,
#  '/m/03j0dp': 290,
#  '/m/025ygws': 291,
#  '/m/09v1lrz': 292,
#  '/m/03f0vvr': 293,
#  '/m/0mhdz': 294,
#  '/m/0q8p8': 295,
#  '/m/01c7p_': 296,
#  '/m/05tbn': 297,
#  '/m/06y3r': 298,
#  '/m/071dcs': 299,
#  '/m/03vyw8': 300,
#  '/m/0ck27z': 301,
#  '/m/02cpp': 302,
#  '/m/073h1t': 303,
#  '/m/087yty': 304,
#  '/m/0466s8n': 305,
#  '/m/016z9n': 306,
#  '/m/0hnf5vm': 307,
#  '/m/04kl74p': 308,
#  '/m/01c6l': 309,
#  '/m/06m6z6': 310,
#  '/m/02jztz': 311,
#  '/m/0bs31sl': 312,
#  '/m/03vrv9': 313,
#  '/m/01f38z': 314,
#  '/m/041jlr': 315,
#  '/m/03hj3b3': 316,
#  '/m/03772': 317,
#  '/m/0jm64': 318,
#  '/m/04255q': 319,
#  '/m/0g284': 320,
#  '/m/03shpq': 321,
#  '/m/03qhyn8': 322,
#  '/m/02mjmr': 323,
#  '/m/026xxv_': 324,
#  '/m/04zwc': 325,
#  '/m/04z257': 326,
#  '/m/016h5l': 327,
#  '/m/01rrgk': 328,
#  '/m/0c4f4': 329,
#  '/m/077g7n': 330,
#  '/m/0fq27fp': 331,
#  '/m/0727_': 332,
#  '/m/059qw': 333,
#  '/m/01_vrh': 334,
#  '/m/011ywj': 335,
#  '/m/065ky': 336,
#  '/m/013n60': 337,
#  '/m/026gvfj': 338,
#  '/m/09cm54': 339,
#  '/m/05bpg3': 340,
#  '/m/026sb55': 341,
#  '/m/0tbr': 342,
#  '/m/01jnzj': 343,
#  '/m/02ps55': 344,
#  '/m/01f9y_': 345,
#  '/m/02fv3t': 346,
#  '/m/0418ft': 347,
#  '/m/0807ml': 348,
#  '/m/03975z': 349,
#  '/m/0677j': 350,
#  '/m/0mlyw': 351,
#  '/m/0hvb2': 352,
#  '/m/013gz': 353,
#  '/m/06wm0z': 354,
#  '/m/01xcgf': 355,
#  '/m/02h8p8': 356,
#  '/m/0gjk1d': 357,
#  '/m/02grjf': 358,
#  '/m/04n36qk': 359,
#  '/m/0bdlj': 360,
#  '/m/02lp0w': 361,
#  '/m/04g7x': 362,
#  '/m/0mlyj': 363,
#  '/m/087c7': 364,
#  '/m/05tg3': 365,
#  '/m/05jnl': 366,
#  '/m/0k345': 367,
#  '/m/01vwbts': 368,
#  '/m/06d4h': 369,
#  '/m/0301yj': 370,
#  '/m/0ywqc': 371,
#  '/m/01k3qj': 372,
#  '/m/02rrfzf': 373,
#  '/m/01vskn': 374,
#  '/m/0739y': 375,
#  '/m/0g7yx': 376,
#  '/m/06w2sn5': 377,
#  '/m/043djx': 378,
#  '/m/085bd1': 379,
#  '/m/013t85': 380,
#  '/m/02_xgp2': 381,
#  '/m/02hvkf': 382,
#  '/m/023k2': 383,
#  '/m/09txzv': 384,
#  '/m/0j1z8': 385,
#  '/m/01vw77': 386,
#  '/m/02vjhf': 387,
#  '/m/0fy2s1': 388,
#  '/m/03gvm3t': 389,
#  '/m/03v1w7': 390,
#  '/m/01cz_1': 391,
#  '/m/0gy1_': 392,
#  '/m/0kcn7': 393,
#  '/m/072hv': 394,
#  '/m/01x2_q': 395,
#  '/m/01zhs3': 396,
#  '/m/07bsj': 397,
#  '/m/0g9k4': 398,
#  '/m/02pr67': 399,
#  '/m/0fbzp': 400,
#  '/m/03cprft': 401,
#  '/m/02q0k7v': 402,
#  '/m/03kmyy': 403,
#  '/m/0f0qfz': 404,
#  '/m/037d35': 405,
#  '/m/08lr6s': 406,
#  '/m/0jym0': 407,
#  '/m/018qpb': 408,
#  '/m/04mlmx': 409,
#  '/m/0lccn': 410,
#  '/m/026njb5': 411,
#  '/m/02qnk5c': 412,
#  '/m/0n9r8': 413,
#  '/m/01rs62': 414,
#  '/m/07yx86': 415,
#  '/m/02lp3c': 416,
#  '/m/02vjzr': 417,
#  '/m/01pny5': 418,
#  '/m/0m9c1': 419,
#  '/m/01m23s': 420,
#  '/m/0bbm7r': 421,
#  '/m/02yv6b': 422,
#  '/m/02_lt': 423,
#  '/m/06s0l': 424,
#  '/m/0fm3nb': 425,
#  '/m/06mm1x': 426,
#  '/m/01fl3': 427,
#  '/m/01cw24': 428,
#  '/m/03gq340': 429,
#  '/m/01fx2g': 430,
#  '/m/04cdxc': 431,
#  '/m/0m19t': 432,
#  '/m/0j_c': 433,
#  '/m/026g51': 434,
#  '/m/02js6_': 435,
#  '/m/064ndc': 436,
#  '/m/03tc8d': 437,
#  '/m/02qfh': 438,
#  '/m/02c_4': 439,
#  '/m/01kx_81': 440,
#  '/m/02vnp2': 441,
#  '/m/012x7b': 442,
#  '/m/061dn_': 443,
#  '/m/0l2xl': 444,
#  '/m/01h910': 445,
#  '/m/0f4l5': 446,
#  '/m/01p1b': 447,
#  '/m/02pfymy': 448,
#  '/m/0cg2cj': 449,
#  '/m/05jm7': 450,
#  '/m/0hvvf': 451,
#  '/m/0pmcz': 452,
#  '/m/05h83': 453,
#  '/m/077qn': 454,
#  '/m/03d2k': 455,
#  '/m/01d_h': 456,
#  '/m/03h_fk5': 457,
#  '/m/05p5nc': 458,
#  '/m/019n9w': 459,
#  '/m/0dn16': 460,
#  '/m/0534v': 461,
#  '/m/044f7': 462,
#  '/m/09d38d': 463,
#  '/m/03qjwc': 464,
#  '/m/0bvz6': 465,
#  '/m/01cvxf': 466,
#  '/m/0127m7': 467,
#  '/m/06hhp': 468,
#  '/m/0h25': 469,
#  '/m/0lzp': 470,
#  '/m/03gyl': 471,
#  '/m/0gcrg': 472,
#  '/m/0l8v5': 473,
#  '/m/0z4_0': 474,
#  '/m/015mlw': 475,
#  '/m/06yrj6': 476,
#  '/m/0b3wk': 477,
#  '/m/02mqc4': 478,
#  '/m/02v49c': 479,
#  '/m/01x7jb': 480,
#  '/m/0m_31': 481,
#  '/m/06_kh': 482,
#  '/m/03nb5v': 483,
#  '/m/03lb76': 484,
#  '/m/031n5b': 485,
#  '/m/06www': 486,
#  '/m/02hczc': 487,
#  '/m/06c44': 488,
#  '/m/0d6lp': 489,
#  '/m/0nlc7': 490,
#  '/m/093g7v': 491,
#  '/m/02wwmhc': 492,
#  '/m/01wqflx': 493,
#  '/m/0kvsb': 494,
#  '/m/03j0ss': 495,
#  '/m/075p0r': 496,
#  '/m/02f72n': 497,
#  '/m/01vvycq': 498,
#  '/m/03193l': 499,
#  '/m/062cg6': 500,
#  '/m/0191_7': 501,
#  '/m/03188': 502,
#  '/m/05s_k6': 503,
#  '/m/08jfkw': 504,
#  '/m/086xm': 505,
#  '/m/04dz_y7': 506,
#  '/m/026h21_': 507,
#  '/m/0kq1l': 508,
#  '/m/05s9tm': 509,
#  '/m/0jnl5': 510,
#  '/m/027y_': 511,
#  '/m/01q3_2': 512,
#  '/m/075wx7_': 513,
#  '/m/0q9mp': 514,
#  '/m/03xb2w': 515,
#  '/m/0425yz': 516,
#  '/m/05pcjw': 517,
#  '/m/0fs44': 518,
#  '/m/0bz5v2': 519,
#  '/m/0bz6sq': 520,
#  '/m/0dgshf6': 521,
#  '/m/04sh80': 522,
#  '/m/0g51l1': 523,
#  '/m/01rl_3': 524,
#  '/m/05q54f5': 525,
#  '/m/03m2fg': 526,
#  '/m/0kvb6p': 527,
#  '/m/01_mdl': 528,
#  '/m/08tq4x': 529,
#  '/m/0lfyx': 530,
#  '/m/02x0dzw': 531,
#  '/m/05wvs': 532,
#  '/m/047s_cr': 533,
#  '/m/03s0c': 534,
#  '/m/03w94xt': 535,
#  '/m/09k0h5': 536,
#  '/m/0jvs0': 537,
#  '/m/07mvp': 538,
#  '/m/02gm9n': 539,
#  '/m/0dgskx': 540,
#  '/m/0mp08': 541,
#  '/m/01v9l67': 542,
#  '/m/02__34': 543,
#  '/m/0p_tz': 544,
#  '/m/01hhvg': 545,
#  '/m/06fvc': 546,
#  '/m/099md': 547,
#  '/m/02w3w': 548,
#  '/m/02xv8m': 549,
#  '/m/0ygbf': 550,
#  '/m/01g7_r': 551,
#  '/m/0gcs9': 552,
#  '/m/02wvf2s': 553,
#  '/m/0sxkh': 554,
#  '/m/0jf1b': 555,
#  '/m/0bmnm': 556,
#  '/m/0r3wm': 557,
#  '/m/059z0': 558,
#  '/m/04bd8y': 559,
#  '/m/034f0d': 560,
#  '/m/02847m9': 561,
#  '/m/0h1zw': 562,
#  '/m/0619m3': 563,
#  '/m/044p4_': 564,
#  '/m/03w1lf': 565,
#  '/m/01k70_': 566,
#  '/m/02bh8z': 567,
#  '/m/07g_0c': 568,
#  '/m/01kkg5': 569,
#  '/m/06f41': 570,
#  '/m/0n5yv': 571,
#  '/m/02j9lm': 572,
#  '/m/05f67hw': 573,
#  '/m/02lm0t': 574,
#  '/m/05gsd2': 575,
#  '/m/0ndwt2w': 576,
#  '/m/056vv': 577,
#  '/m/0mpfn': 578,
#  '/m/01xn7x1': 579,
#  '/m/06dkzt': 580,
#  '/m/02mg7n': 581,
#  '/m/07068': 582,
#  '/m/01h18v': 583,
#  '/m/07h1q': 584,
#  '/m/03bdm4': 585,
#  '/m/09c6w': 586,
#  '/m/07m9cm': 587,
#  '/m/02f764': 588,
#  '/m/02nxhr': 589,
#  '/m/03c6sl9': 590,
#  '/m/0n2k5': 591,
#  '/m/03fpx': 592,
#  '/m/04ls53': 593,
#  '/m/0288crq': 594,
#  '/m/06kl0k': 595,
#  '/m/04110lv': 596,
#  '/m/0cmd3zy': 597,
#  '/m/011yrp': 598,
#  '/m/01l53f': 599,
#  '/m/065dc4': 600,
#  '/m/05cvgl': 601,
#  '/m/04xn2m': 602,
#  '/m/080_y': 603,
#  '/m/0zgfm': 604,
#  '/m/03ywyk': 605,
#  '/m/0187y5': 606,
#  '/m/03cws8h': 607,
#  '/m/03cx282': 608,
#  '/m/0j_1v': 609,
#  '/m/03ckxdg': 610,
#  '/m/01bzs9': 611,
#  '/m/04gp1d': 612,
#  '/m/03x31g': 613,
#  '/m/0ct2tf5': 614,
#  '/m/0gt1k': 615,
#  '/m/09x7p1': 616,
#  '/m/0521d_3': 617,
#  '/m/0167v': 618,
#  '/m/05ftw3': 619,
#  '/m/09w6br': 620,
#  '/m/07nf6': 621,
#  '/m/0pv54': 622,
#  '/m/05g7q': 623,
#  '/m/0gx1l': 624,
#  '/m/01wwvc5': 625,
#  '/m/01qbl': 626,
#  '/m/0124k9': 627,
#  '/m/01sg4_': 628,
#  '/m/04l19_': 629,
#  '/m/0c7f7': 630,
#  '/m/099vwn': 631,
#  '/m/049bp4': 632,
#  '/m/04tqtl': 633,
#  '/m/06w839_': 634,
#  '/m/024bqj': 635,
#  '/m/01s73z': 636,
#  '/m/03_9x6': 637,
#  '/m/02y_rq5': 638,
#  '/m/0fngf': 639,
#  '/m/03gvpk': 640,
#  '/m/02rl201': 641,
#  '/m/0fpjd_g': 642,
#  '/m/0jcx': 643,
#  '/m/01l3wr': 644,
#  '/m/0l8bg': 645,
#  '/m/02whj': 646,
#  '/m/0m93': 647,
#  '/m/02s7tr': 648,
#  '/m/071jv5': 649,
#  '/m/066m4g': 650,
#  '/m/0dprg': 651,
#  '/m/016mhd': 652,
#  '/m/038723': 653,
#  '/m/0hcr': 654,
#  '/m/02hfp_': 655,
#  '/m/08_vwq': 656,
#  '/m/03d8jd1': 657,
#  '/m/0jpn8': 658,
#  '/m/02056s': 659,
#  '/m/03_kl4': 660,
#  '/m/059f4': 661,
#  '/m/068p2': 662,
#  '/m/01lxd4': 663,
#  '/m/01gfhk': 664,
#  '/m/015cl6': 665,
#  '/m/02pjzvh': 666,
#  '/m/03mb9': 667,
#  '/m/0gx_p': 668,
#  '/m/03nk0g': 669,
#  '/m/0q9vf': 670,
#  '/m/0mbhr': 671,
#  '/m/0p9xd': 672,
#  '/m/026ssfj': 673,
#  '/m/0j3b': 674,
#  '/m/02w9sd7': 675,
#  '/m/025vwmy': 676,
#  '/m/03s9kp': 677,
#  '/m/0p7tb': 678,
#  '/m/0cd78': 679,
#  '/m/026ps1': 680,
#  '/m/06lj1m': 681,
#  '/m/013rds': 682,
#  '/m/02q8ms8': 683,
#  '/m/0g2c8': 684,
#  '/m/0k419': 685,
#  '/m/04wg38': 686,
#  '/m/02gn9g': 687,
#  '/m/024sbq': 688,
#  '/m/0fp_v1x': 689,
#  '/m/01v3x8': 690,
#  '/m/0gh6j94': 691,
#  '/m/014gjp': 692,
#  '/m/016475': 693,
#  '/m/0f6cl2': 694,
#  '/m/0dpl44': 695,
#  '/m/043kzcr': 696,
#  '/m/07z1_q': 697,
#  '/m/04kr63w': 698,
#  '/m/04gf49c': 699,
#  '/m/01x209s': 700,
#  '/m/03kx49': 701,
#  '/m/02py8_w': 702,
#  '/m/05zdk2': 703,
#  '/m/07ghq': 704,
#  '/m/02x0gx': 705,
#  '/m/06mnps': 706,
#  '/m/04lgq': 707,
#  '/m/0355dz': 708,
#  '/m/0d063v': 709,
#  '/m/016ks_': 710,
#  '/m/04rvy8': 711,
#  '/m/06vbd': 712,
#  '/m/0lzb8': 713,
#  '/m/02pbrn': 714,
#  '/m/02cbhg': 715,
#  '/m/045zr': 716,
#  '/m/0fr7nt': 717,
#  '/m/03n785': 718,
#  '/m/059j2': 719,
#  '/m/03q5dr': 720,
#  '/m/03rz2b': 721,
#  '/m/06c62': 722,
#  '/m/020trj': 723,
#  '/m/049l7': 724,
#  '/m/03swmf': 725,
#  '/m/0kzcv': 726,
#  '/m/01k8rb': 727,
#  '/m/0bz6l9': 728,
#  '/m/06frc': 729,
#  '/m/016z68': 730,
#  '/m/03z_g7': 731,
#  '/m/028qdb': 732,
#  '/m/013w2r': 733,
#  '/m/04zyhx': 734,
#  '/m/06whf': 735,
#  '/m/07s95_l': 736,
#  '/m/08_yl1': 737,
#  '/m/01wb7': 738,
#  '/m/0ny75': 739,
#  '/m/0j0k': 740,
#  '/m/0bqytm': 741,
#  '/m/0mcl0': 742,
#  '/m/01k5zk': 743,
#  '/m/05nw9m': 744,
#  '/m/01p1z_': 745,
#  '/m/01rdm0': 746,
#  '/m/012s1d': 747,
#  '/m/04fgkf_': 748,
#  '/m/03rbj2': 749,
#  '/m/09wz9': 750,
#  '/m/0bzjf': 751,
#  '/m/03hdz8': 752,
#  '/m/01rgr': 753,
#  '/m/0h1sg': 754,
#  '/m/031zkw': 755,
#  '/m/01tnbn': 756,
#  '/m/036hnm': 757,
#  '/m/042z_g': 758,
#  '/m/03dq9': 759,
#  '/m/053y0s': 760,
#  '/m/01p5yn': 761,
#  '/m/030155': 762,
#  '/m/039g82': 763,
#  '/m/0235l': 764,
#  '/m/0dj7p': 765,
#  '/m/03b_fm5': 766,
#  '/m/05j82v': 767,
#  '/m/05b_gq': 768,
#  '/m/03_3d': 769,
#  '/m/0d05w3': 770,
#  '/m/04znsy': 771,
#  '/m/026r8q': 772,
#  '/m/0b_6x2': 773,
#  '/m/02633g': 774,
#  '/m/03hl6lc': 775,
#  '/m/01gf5h': 776,
#  '/m/013tcv': 777,
#  '/m/01cf93': 778,
#  '/m/05njyy': 779,
#  '/m/0126t5': 780,
#  '/m/03b78r': 781,
#  '/m/0894_x': 782,
#  '/m/04cxw5b': 783,
#  '/m/0qr4n': 784,
#  '/m/05f2jk': 785,
#  '/m/05r3qc': 786,
#  '/m/03bzyn4': 787,
#  '/m/013m_x': 788,
#  '/m/01dyvs': 789,
#  '/m/050sw4': 790,
#  '/m/0flbm': 791,
#  '/m/09k0f': 792,
#  '/m/02wrhj': 793,
#  '/m/031ldd': 794,
#  '/m/0m_v0': 795,
#  '/m/05xf75': 796,
#  '/m/07j8r': 797,
#  '/m/07y9ts': 798,
#  '/m/0k696': 799,
#  '/m/033jj1': 800,
#  '/m/03n08b': 801,
#  '/m/0j95': 802,
#  '/m/0nqv1': 803,
#  '/m/01wbg84': 804,
#  '/m/024_fw': 805,
#  '/m/0cc5mcj': 806,
#  '/m/03fbb6': 807,
#  '/m/01vv7sc': 808,
#  '/m/01b1mj': 809,
#  '/m/01tpl1p': 810,
#  '/m/02s0pp': 811,
#  '/m/076psv': 812,
#  '/m/09fc83': 813,
#  '/m/0y62n': 814,
#  '/m/07cc8': 815,
#  '/m/07yk1xz': 816,
#  '/m/0b6f8pf': 817,
#  '/m/01z_lv': 818,
#  '/m/038981': 819,
#  '/m/0ctb4g': 820,
#  '/m/05cqhl': 821,
#  '/m/01730d': 822,
#  '/m/07c2yr': 823,
#  '/m/07xpm': 824,
#  '/m/01c40n': 825,
#  '/m/03wbqc4': 826,
#  '/m/0c3zjn7': 827,
#  '/m/0vg8': 828,
#  '/m/01n4w': 829,
#  '/m/0pvms': 830,
#  '/m/0q9sg': 831,
#  '/m/06wpc': 832,
#  '/m/063k3h': 833,
#  '/m/01243b': 834,
#  '/m/027l0b': 835,
#  '/m/036qs_': 836,
#  '/m/0d22f': 837,
#  '/m/03mg3l': 838,
#  '/m/027r7k': 839,
#  '/m/04kd5d': 840,
#  '/m/0234pg': 841,
#  '/m/0cg39k': 842,
#  '/m/02lfwp': 843,
#  '/m/0dt49': 844,
#  '/m/01s3vk': 845,
#  '/m/045nc5': 846,
#  '/m/0gfmc_': 847,
#  '/m/05b7q': 848,
#  '/m/02779r4': 849,
#  '/m/03_80b': 850,
#  '/m/040whs': 851,
#  '/m/0dhd5': 852,
#  '/m/08r98b': 853,
#  '/m/02x17c2': 854,
#  '/m/0841zn': 855,
#  '/m/06fp11': 856,
#  '/m/0dcp_': 857,
#  '/m/014knw': 858,
#  '/m/01wj18h': 859,
#  '/m/02d49z': 860,
#  '/m/02d003': 861,
#  '/m/03ly1b': 862,
#  '/m/07z6xs': 863,
#  '/m/02xx5': 864,
#  '/m/0n5by': 865,
#  '/m/02pv_d': 866,
#  '/m/01pm0_': 867,
#  '/m/0c5qvw': 868,
#  '/m/01l63': 869,
#  '/m/0143wl': 870,
#  '/m/0164v': 871,
#  '/m/03fpg': 872,
#  '/m/0cdf37': 873,
#  '/m/03mcwq3': 874,
#  '/m/09fqd3': 875,
#  '/m/05b5_tj': 876,
#  '/m/019z2l': 877,
#  '/m/01wqg8': 878,
#  '/m/0d6n1': 879,
#  '/m/01t9_0': 880,
#  '/m/0kt_4': 881,
#  '/m/014bpd': 882,
#  '/m/0nv5y': 883,
#  '/m/01nhkxp': 884,
#  '/m/0kqj1': 885,
#  '/m/07nqn': 886,
#  '/m/0hskw': 887,
#  '/m/0hz6mv2': 888,
#  '/m/0mgkg': 889,
#  '/m/01w40h': 890,
#  '/m/032r4n': 891,
#  '/m/060m4': 892,
#  '/m/0126rp': 893,
#  '/m/04tr1': 894,
#  '/m/01lvrm': 895,
#  '/m/01wg3q': 896,
#  '/m/0fhp9': 897,
#  '/m/018l5l': 898,
#  '/m/02y5kn': 899,
#  '/m/02sh8y': 900,
#  '/m/0d2by': 901,
#  '/m/01vsy7t': 902,
#  '/m/0dt39': 903,
#  '/m/078g3l': 904,
#  '/m/0cq8qq': 905,
#  '/m/04mp9q': 906,
#  '/m/0jbk9': 907,
#  '/m/01ddth': 908,
#  '/m/0k3nk': 909,
#  '/m/03b3j': 910,
#  '/m/02swsm': 911,
#  '/m/09wnnb': 912,
#  '/m/03vhvp': 913,
#  '/m/070zc': 914,
#  '/m/0308kx': 915,
#  '/m/021_z5': 916,
#  '/m/061681': 917,
#  '/m/03td5v': 918,
#  '/m/01rk91': 919,
#  '/m/0fbq2n': 920,
#  '/m/0gj9qxr': 921,
#  '/m/0chhs': 922,
#  '/m/01vxxb': 923,
#  '/m/0fc9js': 924,
#  '/m/0xpq9': 925,
#  '/m/01sbhvd': 926,
#  '/m/01gb_p': 927,
#  '/m/07sbk': 928,
#  '/m/03fw4y': 929,
#  '/m/01wkmgb': 930,
#  '/m/011k11': 931,
#  '/m/0hrcs29': 932,
#  '/m/0dr_4': 933,
#  '/m/01j_5k': 934,
#  '/m/045xx': 935,
#  '/m/05bnq8': 936,
#  '/m/01pd60': 937,
#  '/m/05511w': 938,
#  '/m/03k50': 939,
#  '/m/02w4fkq': 940,
#  '/m/015_1q': 941,
#  '/m/013h1c': 942,
#  '/m/0515zg': 943,
#  '/m/04z1v0': 944,
#  '/m/052hl': 945,
#  '/m/02mxbd': 946,
#  '/m/0fbtbt': 947,
#  '/m/01wv9p': 948,
#  '/m/02ptczs': 949,
#  '/m/03rl84': 950,
#  '/m/05mxw33': 951,
#  '/m/0b6l1st': 952,
#  '/m/05k2s_': 953,
#  '/m/098s2w': 954,
#  '/m/0fdtd7': 955,
#  '/m/03f2_rc': 956,
#  '/m/0412f5y': 957,
#  '/m/08phg9': 958,
#  '/m/02q_cc': 959,
#  '/m/05vzw3': 960,
#  '/m/01sb5r': 961,
#  '/m/02q3fdr': 962,
#  '/m/0ftlkg': 963,
#  '/m/02b0_m': 964,
#  '/m/015hr': 965,
#  '/m/0cmt6q': 966,
#  '/m/02fybl': 967,
#  '/m/0150n': 968,
#  '/m/06pjs': 969,
#  '/m/03m79j_': 970,
#  '/m/0lz8d': 971,
#  '/m/04dn71w': 972,
#  '/m/02sn34': 973,
#  '/m/025ttz4': 974,
#  '/m/026rsl9': 975,
#  '/m/01nzmp': 976,
#  '/m/0121sr': 977,
#  '/m/01wbsdz': 978,
#  '/m/0n23n': 979,
#  '/m/083p7': 980,
#  '/m/0nk95': 981,
#  '/m/01kf5lf': 982,
#  '/m/01w4dy': 983,
#  '/m/09mq4m': 984,
#  '/m/01mf0': 985,
#  '/m/086h6p': 986,
#  '/m/054lpb6': 987,
#  '/m/02b149': 988,
#  '/m/01fx5l': 989,
#  '/m/053rd': 990,
#  '/m/0853g': 991,
#  '/m/050r1z': 992,
#  '/m/02r6c_': 993,
#  '/m/07db6x': 994,
#  '/m/070ny': 995,
#  '/m/0b_6lb': 996,
#  '/m/02qyntr': 997,
#  '/m/04xhwn': 998,
#  '/m/05krk': 999,
#  ...}

# %%
model.dict_rel2id
# Out:
# {'/government/politician/government_positions_held./government/government_position_held/basic_title': 0,
#  '/award/award_nominee/award_nominations./award/award_nomination/award': 1,
#  '/sports/sports_team/roster./american_football/football_roster_position/position': 2,
#  '/sports/sports_team/roster./basketball/basketball_roster_position/position': 3,
#  '/broadcast/content/artist': 4,
#  '/base/biblioness/bibs_location/country': 5,
#  '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film': 6,
#  '/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team': 7,
#  '/user/alexander/philosophy/philosopher/interests': 8,
#  '/baseball/baseball_team/team_stats./baseball/baseball_team_stats/season': 9,
#  '/base/biblioness/bibs_location/state': 10,
#  '/influence/influence_node/peers./influence/peer_relationship/peers': 11,
#  '/award/award_winning_work/awards_won./award/award_honor/award': 12,
#  '/music/artist/track_contributions./music/track_contribution/role': 13,
#  '/sports/sports_team/colors': 14,
#  '/education/educational_degree/people_with_this_degree./education/education/major_field_of_study': 15,
#  '/government/governmental_body/members./government/government_position_held/legislative_sessions': 16,
#  '/film/film/film_format': 17,
#  '/music/genre/artists': 18,
#  '/location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division': 19,
#  '/film/film/costume_design_by': 20,
#  '/sports/sports_position/players./sports/sports_team_roster/team': 21,
#  '/location/location/contains': 22,
#  '/film/film_set_designer/film_sets_designed': 23,
#  '/tv/tv_network/programs./tv/tv_network_duration/program': 24,
#  '/location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency': 25,
#  '/music/instrument/instrumentalists': 26,
#  '/sports/sport/pro_athletes./sports/pro_sports_played/athlete': 27,
#  '/people/person/profession': 28,
#  '/government/legislative_session/members./government/government_position_held/district_represented': 29,
#  '/award/award_nominee/award_nominations./award/award_nomination/nominated_for': 30,
#  '/education/university/fraternities_and_sororities': 31,
#  '/music/instrument/family': 32,
#  '/music/record_label/artist': 33,
#  '/business/business_operation/operating_income./measurement_unit/dated_money_value/currency': 34,
#  '/people/deceased_person/place_of_burial': 35,
#  '/base/popstra/celebrity/canoodled./base/popstra/canoodled/participant': 36,
#  '/award/award_ceremony/awards_presented./award/award_honor/award_winner': 37,
#  '/government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office': 38,
#  '/tv/tv_program/genre': 39,
#  '/education/educational_institution/students_graduates./education/education/major_field_of_study': 40,
#  '/film/film/music': 41,
#  '/organization/organization/headquarters./location/mailing_address/country': 42,
#  '/military/military_conflict/combatants./military/military_combatant_group/combatants': 43,
#  '/education/educational_institution/students_graduates./education/education/student': 44,
#  '/award/award_winner/awards_won./award/award_honor/award_winner': 45,
#  '/music/group_member/membership./music/group_membership/role': 46,
#  '/media_common/netflix_genre/titles': 47,
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location': 48,
#  '/music/performance_role/guest_performances./music/recording_contribution/performance_role': 49,
#  '/organization/organization/child./organization/organization_relationship/child': 50,
#  '/dataworld/gardening_hint/split_to': 51,
#  '/award/award_ceremony/awards_presented./award/award_honor/honored_for': 52,
#  '/base/americancomedy/celebrity_impressionist/celebrities_impersonated': 53,
#  '/influence/influence_node/influenced_by': 54,
#  '/tv/tv_program/languages': 55,
#  '/travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation': 56,
#  '/time/event/locations': 57,
#  '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics': 58,
#  '/food/food/nutrients./food/nutrition_fact/nutrient': 59,
#  '/celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity': 60,
#  '/ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position': 61,
#  '/base/popstra/celebrity/friendship./base/popstra/friendship/participant': 62,
#  '/music/performance_role/track_performances./music/track_contribution/role': 63,
#  '/people/ethnicity/people': 64,
#  '/film/film/cinematography': 65,
#  '/people/person/places_lived./people/place_lived/location': 66,
#  '/film/film/featured_film_locations': 67,
#  '/sports/sports_league/teams./sports/sports_league_participation/team': 68,
#  '/tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program': 69,
#  '/language/human_language/countries_spoken_in': 70,
#  '/organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency': 71,
#  '/medicine/disease/notable_people_with_this_condition': 72,
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category': 73,
#  '/tv/tv_program/regular_cast./tv/regular_tv_appearance/actor': 74,
#  '/film/film/prequel': 75,
#  '/film/actor/film./film/performance/film': 76,
#  '/location/location/adjoin_s./location/adjoining_relationship/adjoins': 77,
#  '/american_football/football_team/current_roster./sports/sports_team_roster/position': 78,
#  '/business/business_operation/assets./measurement_unit/dated_money_value/currency': 79,
#  '/education/university/domestic_tuition./measurement_unit/dated_money_value/currency': 80,
#  '/location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency': 81,
#  '/film/film/written_by': 82,
#  '/people/person/sibling_s./people/sibling_relationship/sibling': 83,
#  '/film/film/runtime./film/film_cut/film_release_region': 84,
#  '/celebrities/celebrity/celebrity_friends./celebrities/friendship/friend': 85,
#  '/education/educational_degree/people_with_this_degree./education/education/institution': 86,
#  '/film/film/personal_appearances./film/personal_film_appearance/person': 87,
#  '/people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony': 88,
#  '/education/educational_institution/school_type': 89,
#  '/tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program': 90,
#  '/location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source': 91,
#  '/organization/organization/headquarters./location/mailing_address/citytown': 92,
#  '/film/film/story_by': 93,
#  '/organization/role/leaders./organization/leadership/organization': 94,
#  '/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed': 95,
#  '/people/person/employment_history./business/employment_tenure/company': 96,
#  '/government/political_party/politicians_in_this_party./government/political_party_tenure/politician': 97,
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language': 98,
#  '/film/film/produced_by': 99,
#  '/sports/sports_team/sport': 100,
#  '/organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency': 101,
#  '/education/educational_degree/people_with_this_degree./education/education/student': 102,
#  '/award/award_category/winners./award/award_honor/award_winner': 103,
#  '/government/legislative_session/members./government/government_position_held/legislative_sessions': 104,
#  '/sports/sports_league_draft/picks./sports/sports_league_draft_pick/school': 105,
#  '/user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy': 106,
#  '/location/us_county/county_seat': 107,
#  '/film/film/film_art_direction_by': 108,
#  '/medicine/disease/risk_factors': 109,
#  '/education/educational_institution_campus/educational_institution': 110,
#  '/people/person/gender': 111,
#  '/film/film_subject/films': 112,
#  '/award/award_winning_work/awards_won./award/award_honor/honored_for': 113,
#  '/award/award_category/winners./award/award_honor/ceremony': 114,
#  '/people/person/spouse_s./people/marriage/spouse': 115,
#  '/tv/tv_program/program_creator': 116,
#  '/user/jg/default_domain/olympic_games/sports': 117,
#  '/film/film/estimated_budget./measurement_unit/dated_money_value/currency': 118,
#  '/olympics/olympic_games/participating_countries': 119,
#  '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft': 120,
#  '/location/administrative_division/country': 121,
#  '/sports/sports_position/players./american_football/football_historical_roster_position/position_s': 122,
#  '/people/person/spouse_s./people/marriage/location_of_ceremony': 123,
#  '/base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months': 124,
#  '/film/film/release_date_s./film/film_regional_release_date/film_regional_debut_venue': 125,
#  '/film/film/language': 126,
#  '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency': 127,
#  '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school': 128,
#  '/education/educational_institution/colors': 129,
#  '/base/aareas/schema/administrative_area/administrative_parent': 130,
#  '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country': 131,
#  '/film/film/genre': 132,
#  '/base/popstra/celebrity/dated./base/popstra/dated/participant': 133,
#  '/film/film/release_date_s./film/film_regional_release_date/film_release_region': 134,
#  '/film/film/country': 135,
#  '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics': 136,
#  '/base/popstra/celebrity/breakup./base/popstra/breakup/participant': 137,
#  '/tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type': 138,
#  '/film/film/executive_produced_by': 139,
#  '/military/military_combatant/military_conflicts./military/military_combatant_group/combatants': 140,
#  '/people/person/nationality': 141,
#  '/award/award_category/disciplines_or_subjects': 142,
#  '/people/ethnicity/geographic_distribution': 143,
#  '/music/artist/origin': 144,
#  '/location/hud_county_place/county': 145,
#  '/location/country/second_level_divisions': 146,
#  '/education/university/local_tuition./measurement_unit/dated_money_value/currency': 147,
#  '/location/country/official_language': 148,
#  '/film/special_film_performance_type/film_performance_type./film/performance/film': 149,
#  '/film/actor/film./film/performance/special_performance_type': 150,
#  '/music/performance_role/regular_performances./music/group_membership/role': 151,
#  '/sports/sports_team/roster./american_football/football_historical_roster_position/position_s': 152,
#  '/location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency': 153,
#  '/award/award_winning_work/awards_won./award/award_honor/award_winner': 154,
#  '/business/business_operation/revenue./measurement_unit/dated_money_value/currency': 155,
#  '/location/location/time_zones': 156,
#  '/music/group_member/membership./music/group_membership/group': 157,
#  '/film/film/film_production_design_by': 158,
#  '/education/field_of_study/students_majoring./education/education/major_field_of_study': 159,
#  '/film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance': 160,
#  '/location/statistical_region/places_exported_to./location/imports_and_exports/exported_to': 161,
#  '/location/location/partially_contains': 162,
#  '/sports/sports_position/players./sports/sports_team_roster/position': 163,
#  '/organization/organization/place_founded': 164,
#  '/music/genre/parent_genre': 165,
#  '/base/culturalevent/event/entity_involved': 166,
#  '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics': 167,
#  '/location/statistical_region/religions./location/religion_percentage/religion': 168,
#  '/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer': 169,
#  '/tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person': 170,
#  '/time/event/instance_of_recurring_event': 171,
#  '/award/ranked_item/appears_in_ranked_lists./award/ranking/list': 172,
#  '/travel/travel_destination/climate./travel/travel_destination_monthly_climate/month': 173,
#  '/people/profession/specialization_of': 174,
#  '/olympics/olympic_games/sports': 175,
#  '/sports/pro_athlete/teams./sports/sports_team_roster/team': 176,
#  '/award/award_nominee/award_nominations./award/award_nomination/award_nominee': 177,
#  '/people/cause_of_death/people': 178,
#  '/olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal': 179,
#  '/location/hud_county_place/place': 180,
#  '/sports/sports_team_location/teams': 181,
#  '/base/locations/continents/countries_within': 182,
#  '/film/director/film': 183,
#  '/sports/sports_team/roster./baseball/baseball_roster_position/position': 184,
#  '/award/award_nominated_work/award_nominations./award/award_nomination/nominated_for': 185,
#  '/people/deceased_person/place_of_death': 186,
#  '/people/person/languages': 187,
#  '/people/ethnicity/languages_spoken': 188,
#  '/business/job_title/people_with_this_title./business/employment_tenure/company': 189,
#  '/tv/tv_program/country_of_origin': 190,
#  '/people/person/religion': 191,
#  '/base/aareas/schema/administrative_area/administrative_area_type': 192,
#  '/location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency': 193,
#  '/base/eating/practicer_of_diet/diet': 194,
#  '/location/administrative_division/first_level_division_of': 195,
#  '/award/award_category/nominees./award/award_nomination/nominated_for': 196,
#  '/film/film/film_festivals': 197,
#  '/organization/organization_member/member_of./organization/organization_membership/organization': 198,
#  '/film/film/other_crew./film/film_crew_gig/crewmember': 199,
#  '/film/film/production_companies': 200,
#  '/base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members': 201,
#  '/organization/organization/headquarters./location/mailing_address/state_province_region': 202,
#  '/location/country/capital': 203,
#  '/education/university/international_tuition./measurement_unit/dated_money_value/currency': 204,
#  '/government/politician/government_positions_held./government/government_position_held/legislative_sessions': 205,
#  '/government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office': 206,
#  '/location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency': 207,
#  '/education/field_of_study/students_majoring./education/education/student': 208,
#  '/people/person/place_of_birth': 209,
#  '/organization/organization_founder/organizations_founded': 210,
#  '/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club': 211,
#  '/tv/tv_producer/programs_produced./tv/tv_producer_term/program': 212,
#  '/film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium': 213,
#  '/education/educational_institution/campuses': 214,
#  '/award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee': 215,
#  '/business/business_operation/industry': 216,
#  '/film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium': 217,
#  '/soccer/football_team/current_roster./sports/sports_team_roster/position': 218,
#  '/tv/tv_program/tv_producer./tv/tv_producer_term/producer_type': 219,
#  '/film/film/edited_by': 220,
#  '/film/film/other_crew./film/film_crew_gig/film_crew_role': 221,
#  '/user/ktrueman/default_domain/international_organization/member_states': 222,
#  '/medicine/symptom/symptom_of': 223,
#  '/base/aareas/schema/administrative_area/capital': 224,
#  '/location/country/form_of_government': 225,
#  '/award/award_category/category_of': 226,
#  '/soccer/football_team/current_roster./soccer/football_roster_position/position': 227,
#  '/common/topic/webpage./common/webpage/category': 228,
#  '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal': 229,
#  '/film/film/distributors./film/film_film_distributor_relationship/region': 230,
#  '/people/person/spouse_s./people/marriage/type_of_union': 231,
#  '/music/performance_role/regular_performances./music/group_membership/group': 232,
#  '/soccer/football_player/current_team./sports/sports_team_roster/team': 233,
#  '/film/film/dubbing_performances./film/dubbing_performance/actor': 234,
#  '/film/actor/dubbing_performances./film/dubbing_performance/language': 235,
#  '/music/artist/contribution./music/recording_contribution/performance_role': 236}

# %%
model.dict_id2ent
# Out:
# ['/m/015ynm',
#  '/m/0dp7wt',
#  '/m/01z8f0',
#  '/m/0m491',
#  '/m/012201',
#  '/m/0906w9',
#  '/m/07_pf',
#  '/m/0g0vx',
#  '/m/023mdt',
#  '/m/0kjrx',
#  '/m/030qb3t',
#  '/m/0138mv',
#  '/m/03v0t',
#  '/m/06mr6',
#  '/m/07ldhs',
#  '/m/01vxqyl',
#  '/m/0gwgn1k',
#  '/m/01jqr_5',
#  '/m/05j0wc',
#  '/m/06f32',
#  '/m/046n4q',
#  '/m/0882r_',
#  '/m/0gq6s3',
#  '/m/0bvzp',
#  '/m/01nfys',
#  '/m/0fj9f',
#  '/m/02psgq',
#  '/m/03dhbp',
#  '/m/018gqj',
#  '/m/016vqk',
#  '/m/03zw80',
#  '/m/05btx9',
#  '/m/0fw9n7',
#  '/m/051n13',
#  '/m/03z9585',
#  '/m/01817f',
#  '/m/01r4k',
#  '/m/044l47',
#  '/m/01wrcxr',
#  '/m/02z3cm0',
#  '/m/02lhm2',
#  '/m/0l4vc',
#  '/m/07sc6nw',
#  '/m/01k2yr',
#  '/m/05y0cr',
#  '/m/01dhmw',
#  '/m/034np8',
#  '/m/0dmy0',
#  '/m/0g7pm',
#  '/m/019mdt',
#  '/m/023b97',
#  '/m/0g5ff',
#  '/m/02kxbx3',
#  '/m/0443xn',
#  '/m/09qgm',
#  '/m/01kgxf',
#  '/m/0mwh1',
#  '/m/0l9k1',
#  '/m/047sxrj',
#  '/m/03bdv',
#  '/m/046b0s',
#  '/m/02w7gg',
#  '/m/0gj8nq2',
#  '/m/018q7',
#  '/m/09cdxn',
#  '/m/015y2q',
#  '/m/098s1',
#  '/m/02yv_b',
#  '/m/029skd',
#  '/m/01n8_g',
#  '/m/01nx_8',
#  '/m/01qkqwg',
#  '/m/01y8cr',
#  '/m/035qlx',
#  '/m/03b0q4',
#  '/m/0cw3yd',
#  '/m/029sk',
#  '/m/01dzq6',
#  '/m/0l8z1',
#  '/m/01bbwp',
#  '/m/01bj6y',
#  '/m/0dbc1s',
#  '/m/01516r',
#  '/m/045gzq',
#  '/m/0466k4',
#  '/m/0c58k',
#  '/m/016gb5',
#  '/m/0bx_f_t',
#  '/m/013c6x',
#  '/m/0dc_v',
#  '/m/0124ld',
#  '/m/045m1_',
#  '/m/030h95',
#  '/m/0c422z4',
#  '/m/087v17',
#  '/m/02bbyw',
#  '/m/02j8z',
#  '/m/0m5s5',
#  '/m/02x08c',
#  '/m/01d1yr',
#  '/m/01jv_6',
#  '/m/0k4f3',
#  '/m/023kzp',
#  '/m/0qmjd',
#  '/m/04wvhz',
#  '/m/05v38p',
#  '/m/025n3p',
#  '/m/0537y_',
#  '/m/0jw67',
#  '/m/01f7v_',
#  '/m/01v3rb',
#  '/m/02rn00y',
#  '/m/02lyr4',
#  '/m/02gvwz',
#  '/m/0k4y6',
#  '/m/07wlf',
#  '/m/02h758',
#  '/m/0639bg',
#  '/m/0dlw0',
#  '/m/07gghl',
#  '/m/07f7jp',
#  '/m/01pdgp',
#  '/m/03kts',
#  '/m/0n5_g',
#  '/m/0515_6',
#  '/m/01314k',
#  '/m/0bpm4yw',
#  '/m/04pqqb',
#  '/m/085ccd',
#  '/m/038c0q',
#  '/m/03q0r1',
#  '/m/02gx2x',
#  '/m/034g2b',
#  '/m/01kc4s',
#  '/m/06b19',
#  '/m/060ppp',
#  '/m/0f13b',
#  '/m/02qsfzv',
#  '/m/0h3mrc',
#  '/m/021npv',
#  '/m/01x53m',
#  '/m/0cqt90',
#  '/m/0f1nl',
#  '/m/0sngf',
#  '/m/0ml25',
#  '/m/0ckhc',
#  '/m/0c41qv',
#  '/m/032f6',
#  '/m/040p_q',
#  '/m/01w4c9',
#  '/m/08k1lz',
#  '/m/025y67',
#  '/m/0gzh',
#  '/m/01j851',
#  '/m/0b0nq2',
#  '/m/03gyp30',
#  '/m/04v09',
#  '/m/01hnp',
#  '/m/0ch280',
#  '/m/03fmfs',
#  '/m/0ys4f',
#  '/m/0c00zd0',
#  '/m/02630g',
#  '/m/0g96wd',
#  '/m/01qhm_',
#  '/m/03h_f4',
#  '/m/02d6n_',
#  '/m/027pfb2',
#  '/m/01vd7hn',
#  '/m/0cymln',
#  '/m/0k2h6',
#  '/m/01nf9x',
#  '/m/043vc',
#  '/m/03t5n3',
#  '/m/01x15dc',
#  '/m/0tlq9',
#  '/m/03hxsv',
#  '/m/017c87',
#  '/m/04h4c9',
#  '/m/030p35',
#  '/m/02f8lw',
#  '/m/0q8sw',
#  '/m/05d49',
#  '/m/02r6mf',
#  '/m/0fz0c2',
#  '/m/02f8zw',
#  '/m/05jx2d',
#  '/m/03gj2',
#  '/m/02g5q1',
#  '/m/014vk4',
#  '/m/02k76g',
#  '/m/013b2h',
#  '/m/026fd',
#  '/m/0kpzy',
#  '/m/04b5l3',
#  '/m/02cqny',
#  '/m/02k54',
#  '/m/09p7fh',
#  '/m/02f77y',
#  '/m/01lly5',
#  '/m/05lb87',
#  '/m/0h8d',
#  '/m/02gt5s',
#  '/m/02681vq',
#  '/m/05m_jsg',
#  '/m/0dr7s',
#  '/m/080lkt7',
#  '/m/02qssrm',
#  '/m/01f9zw',
#  '/m/042v2',
#  '/m/0hnlx',
#  '/m/0gr36',
#  '/m/0gw0',
#  '/m/04bnx',
#  '/m/06rrzn',
#  '/m/0b6k40',
#  '/m/09s02',
#  '/m/01ly8d',
#  '/m/013719',
#  '/m/070c93',
#  '/m/01gqg3',
#  '/m/0gqwc',
#  '/m/0rrhp',
#  '/m/019cr',
#  '/m/0257yf',
#  '/m/0195pd',
#  '/m/0mskq',
#  '/m/02f71y',
#  '/m/057xs89',
#  '/m/02s2lg',
#  '/m/023zl',
#  '/m/043gj',
#  '/m/02nygk',
#  '/m/0bl1_',
#  '/m/0dxmyh',
#  '/m/0r1jr',
#  '/m/023s8',
#  '/m/018dh3',
#  '/m/0bk25',
#  '/m/0flw6',
#  '/m/04zw9hs',
#  '/m/0513yzt',
#  '/m/0436kgz',
#  '/m/0cv72h',
#  '/m/0c01c',
#  '/m/0b005',
#  '/m/0_816',
#  '/m/04pry',
#  '/m/0nj0m',
#  '/m/0k5p1',
#  '/m/02q3n9c',
#  '/m/0tc7',
#  '/m/02tqm5',
#  '/m/059x0w',
#  '/m/057n_g',
#  '/m/03q3x5',
#  '/m/02dlfh',
#  '/m/038_l',
#  '/m/03y5ky',
#  '/m/01skqzw',
#  '/m/0njlp',
#  '/m/0hvjr',
#  '/m/0jnrk',
#  '/m/06cmp',
#  '/m/0b_yz',
#  '/m/0m32_',
#  '/m/03f0324',
#  '/m/0bdxs5',
#  '/m/02kc4sf',
#  '/m/04jn6y7',
#  '/m/0lh0c',
#  '/m/01ym8l',
#  '/m/02d44q',
#  '/m/024_41',
#  '/m/03ryzs',
#  '/m/01q2sk',
#  '/m/0ncj8',
#  '/m/03zg2x',
#  '/m/01tmtg',
#  '/m/05wkw',
#  '/m/050llt',
#  '/m/03ncb2',
#  '/m/01vw917',
#  '/m/01dpdh',
#  '/m/01g5v',
#  '/m/0168dy',
#  '/m/0b275x',
#  '/m/04fv0k',
#  '/m/03d96s',
#  '/m/0105y2',
#  '/m/03j0dp',
#  '/m/025ygws',
#  '/m/09v1lrz',
#  '/m/03f0vvr',
#  '/m/0mhdz',
#  '/m/0q8p8',
#  '/m/01c7p_',
#  '/m/05tbn',
#  '/m/06y3r',
#  '/m/071dcs',
#  '/m/03vyw8',
#  '/m/0ck27z',
#  '/m/02cpp',
#  '/m/073h1t',
#  '/m/087yty',
#  '/m/0466s8n',
#  '/m/016z9n',
#  '/m/0hnf5vm',
#  '/m/04kl74p',
#  '/m/01c6l',
#  '/m/06m6z6',
#  '/m/02jztz',
#  '/m/0bs31sl',
#  '/m/03vrv9',
#  '/m/01f38z',
#  '/m/041jlr',
#  '/m/03hj3b3',
#  '/m/03772',
#  '/m/0jm64',
#  '/m/04255q',
#  '/m/0g284',
#  '/m/03shpq',
#  '/m/03qhyn8',
#  '/m/02mjmr',
#  '/m/026xxv_',
#  '/m/04zwc',
#  '/m/04z257',
#  '/m/016h5l',
#  '/m/01rrgk',
#  '/m/0c4f4',
#  '/m/077g7n',
#  '/m/0fq27fp',
#  '/m/0727_',
#  '/m/059qw',
#  '/m/01_vrh',
#  '/m/011ywj',
#  '/m/065ky',
#  '/m/013n60',
#  '/m/026gvfj',
#  '/m/09cm54',
#  '/m/05bpg3',
#  '/m/026sb55',
#  '/m/0tbr',
#  '/m/01jnzj',
#  '/m/02ps55',
#  '/m/01f9y_',
#  '/m/02fv3t',
#  '/m/0418ft',
#  '/m/0807ml',
#  '/m/03975z',
#  '/m/0677j',
#  '/m/0mlyw',
#  '/m/0hvb2',
#  '/m/013gz',
#  '/m/06wm0z',
#  '/m/01xcgf',
#  '/m/02h8p8',
#  '/m/0gjk1d',
#  '/m/02grjf',
#  '/m/04n36qk',
#  '/m/0bdlj',
#  '/m/02lp0w',
#  '/m/04g7x',
#  '/m/0mlyj',
#  '/m/087c7',
#  '/m/05tg3',
#  '/m/05jnl',
#  '/m/0k345',
#  '/m/01vwbts',
#  '/m/06d4h',
#  '/m/0301yj',
#  '/m/0ywqc',
#  '/m/01k3qj',
#  '/m/02rrfzf',
#  '/m/01vskn',
#  '/m/0739y',
#  '/m/0g7yx',
#  '/m/06w2sn5',
#  '/m/043djx',
#  '/m/085bd1',
#  '/m/013t85',
#  '/m/02_xgp2',
#  '/m/02hvkf',
#  '/m/023k2',
#  '/m/09txzv',
#  '/m/0j1z8',
#  '/m/01vw77',
#  '/m/02vjhf',
#  '/m/0fy2s1',
#  '/m/03gvm3t',
#  '/m/03v1w7',
#  '/m/01cz_1',
#  '/m/0gy1_',
#  '/m/0kcn7',
#  '/m/072hv',
#  '/m/01x2_q',
#  '/m/01zhs3',
#  '/m/07bsj',
#  '/m/0g9k4',
#  '/m/02pr67',
#  '/m/0fbzp',
#  '/m/03cprft',
#  '/m/02q0k7v',
#  '/m/03kmyy',
#  '/m/0f0qfz',
#  '/m/037d35',
#  '/m/08lr6s',
#  '/m/0jym0',
#  '/m/018qpb',
#  '/m/04mlmx',
#  '/m/0lccn',
#  '/m/026njb5',
#  '/m/02qnk5c',
#  '/m/0n9r8',
#  '/m/01rs62',
#  '/m/07yx86',
#  '/m/02lp3c',
#  '/m/02vjzr',
#  '/m/01pny5',
#  '/m/0m9c1',
#  '/m/01m23s',
#  '/m/0bbm7r',
#  '/m/02yv6b',
#  '/m/02_lt',
#  '/m/06s0l',
#  '/m/0fm3nb',
#  '/m/06mm1x',
#  '/m/01fl3',
#  '/m/01cw24',
#  '/m/03gq340',
#  '/m/01fx2g',
#  '/m/04cdxc',
#  '/m/0m19t',
#  '/m/0j_c',
#  '/m/026g51',
#  '/m/02js6_',
#  '/m/064ndc',
#  '/m/03tc8d',
#  '/m/02qfh',
#  '/m/02c_4',
#  '/m/01kx_81',
#  '/m/02vnp2',
#  '/m/012x7b',
#  '/m/061dn_',
#  '/m/0l2xl',
#  '/m/01h910',
#  '/m/0f4l5',
#  '/m/01p1b',
#  '/m/02pfymy',
#  '/m/0cg2cj',
#  '/m/05jm7',
#  '/m/0hvvf',
#  '/m/0pmcz',
#  '/m/05h83',
#  '/m/077qn',
#  '/m/03d2k',
#  '/m/01d_h',
#  '/m/03h_fk5',
#  '/m/05p5nc',
#  '/m/019n9w',
#  '/m/0dn16',
#  '/m/0534v',
#  '/m/044f7',
#  '/m/09d38d',
#  '/m/03qjwc',
#  '/m/0bvz6',
#  '/m/01cvxf',
#  '/m/0127m7',
#  '/m/06hhp',
#  '/m/0h25',
#  '/m/0lzp',
#  '/m/03gyl',
#  '/m/0gcrg',
#  '/m/0l8v5',
#  '/m/0z4_0',
#  '/m/015mlw',
#  '/m/06yrj6',
#  '/m/0b3wk',
#  '/m/02mqc4',
#  '/m/02v49c',
#  '/m/01x7jb',
#  '/m/0m_31',
#  '/m/06_kh',
#  '/m/03nb5v',
#  '/m/03lb76',
#  '/m/031n5b',
#  '/m/06www',
#  '/m/02hczc',
#  '/m/06c44',
#  '/m/0d6lp',
#  '/m/0nlc7',
#  '/m/093g7v',
#  '/m/02wwmhc',
#  '/m/01wqflx',
#  '/m/0kvsb',
#  '/m/03j0ss',
#  '/m/075p0r',
#  '/m/02f72n',
#  '/m/01vvycq',
#  '/m/03193l',
#  '/m/062cg6',
#  '/m/0191_7',
#  '/m/03188',
#  '/m/05s_k6',
#  '/m/08jfkw',
#  '/m/086xm',
#  '/m/04dz_y7',
#  '/m/026h21_',
#  '/m/0kq1l',
#  '/m/05s9tm',
#  '/m/0jnl5',
#  '/m/027y_',
#  '/m/01q3_2',
#  '/m/075wx7_',
#  '/m/0q9mp',
#  '/m/03xb2w',
#  '/m/0425yz',
#  '/m/05pcjw',
#  '/m/0fs44',
#  '/m/0bz5v2',
#  '/m/0bz6sq',
#  '/m/0dgshf6',
#  '/m/04sh80',
#  '/m/0g51l1',
#  '/m/01rl_3',
#  '/m/05q54f5',
#  '/m/03m2fg',
#  '/m/0kvb6p',
#  '/m/01_mdl',
#  '/m/08tq4x',
#  '/m/0lfyx',
#  '/m/02x0dzw',
#  '/m/05wvs',
#  '/m/047s_cr',
#  '/m/03s0c',
#  '/m/03w94xt',
#  '/m/09k0h5',
#  '/m/0jvs0',
#  '/m/07mvp',
#  '/m/02gm9n',
#  '/m/0dgskx',
#  '/m/0mp08',
#  '/m/01v9l67',
#  '/m/02__34',
#  '/m/0p_tz',
#  '/m/01hhvg',
#  '/m/06fvc',
#  '/m/099md',
#  '/m/02w3w',
#  '/m/02xv8m',
#  '/m/0ygbf',
#  '/m/01g7_r',
#  '/m/0gcs9',
#  '/m/02wvf2s',
#  '/m/0sxkh',
#  '/m/0jf1b',
#  '/m/0bmnm',
#  '/m/0r3wm',
#  '/m/059z0',
#  '/m/04bd8y',
#  '/m/034f0d',
#  '/m/02847m9',
#  '/m/0h1zw',
#  '/m/0619m3',
#  '/m/044p4_',
#  '/m/03w1lf',
#  '/m/01k70_',
#  '/m/02bh8z',
#  '/m/07g_0c',
#  '/m/01kkg5',
#  '/m/06f41',
#  '/m/0n5yv',
#  '/m/02j9lm',
#  '/m/05f67hw',
#  '/m/02lm0t',
#  '/m/05gsd2',
#  '/m/0ndwt2w',
#  '/m/056vv',
#  '/m/0mpfn',
#  '/m/01xn7x1',
#  '/m/06dkzt',
#  '/m/02mg7n',
#  '/m/07068',
#  '/m/01h18v',
#  '/m/07h1q',
#  '/m/03bdm4',
#  '/m/09c6w',
#  '/m/07m9cm',
#  '/m/02f764',
#  '/m/02nxhr',
#  '/m/03c6sl9',
#  '/m/0n2k5',
#  '/m/03fpx',
#  '/m/04ls53',
#  '/m/0288crq',
#  '/m/06kl0k',
#  '/m/04110lv',
#  '/m/0cmd3zy',
#  '/m/011yrp',
#  '/m/01l53f',
#  '/m/065dc4',
#  '/m/05cvgl',
#  '/m/04xn2m',
#  '/m/080_y',
#  '/m/0zgfm',
#  '/m/03ywyk',
#  '/m/0187y5',
#  '/m/03cws8h',
#  '/m/03cx282',
#  '/m/0j_1v',
#  '/m/03ckxdg',
#  '/m/01bzs9',
#  '/m/04gp1d',
#  '/m/03x31g',
#  '/m/0ct2tf5',
#  '/m/0gt1k',
#  '/m/09x7p1',
#  '/m/0521d_3',
#  '/m/0167v',
#  '/m/05ftw3',
#  '/m/09w6br',
#  '/m/07nf6',
#  '/m/0pv54',
#  '/m/05g7q',
#  '/m/0gx1l',
#  '/m/01wwvc5',
#  '/m/01qbl',
#  '/m/0124k9',
#  '/m/01sg4_',
#  '/m/04l19_',
#  '/m/0c7f7',
#  '/m/099vwn',
#  '/m/049bp4',
#  '/m/04tqtl',
#  '/m/06w839_',
#  '/m/024bqj',
#  '/m/01s73z',
#  '/m/03_9x6',
#  '/m/02y_rq5',
#  '/m/0fngf',
#  '/m/03gvpk',
#  '/m/02rl201',
#  '/m/0fpjd_g',
#  '/m/0jcx',
#  '/m/01l3wr',
#  '/m/0l8bg',
#  '/m/02whj',
#  '/m/0m93',
#  '/m/02s7tr',
#  '/m/071jv5',
#  '/m/066m4g',
#  '/m/0dprg',
#  '/m/016mhd',
#  '/m/038723',
#  '/m/0hcr',
#  '/m/02hfp_',
#  '/m/08_vwq',
#  '/m/03d8jd1',
#  '/m/0jpn8',
#  '/m/02056s',
#  '/m/03_kl4',
#  '/m/059f4',
#  '/m/068p2',
#  '/m/01lxd4',
#  '/m/01gfhk',
#  '/m/015cl6',
#  '/m/02pjzvh',
#  '/m/03mb9',
#  '/m/0gx_p',
#  '/m/03nk0g',
#  '/m/0q9vf',
#  '/m/0mbhr',
#  '/m/0p9xd',
#  '/m/026ssfj',
#  '/m/0j3b',
#  '/m/02w9sd7',
#  '/m/025vwmy',
#  '/m/03s9kp',
#  '/m/0p7tb',
#  '/m/0cd78',
#  '/m/026ps1',
#  '/m/06lj1m',
#  '/m/013rds',
#  '/m/02q8ms8',
#  '/m/0g2c8',
#  '/m/0k419',
#  '/m/04wg38',
#  '/m/02gn9g',
#  '/m/024sbq',
#  '/m/0fp_v1x',
#  '/m/01v3x8',
#  '/m/0gh6j94',
#  '/m/014gjp',
#  '/m/016475',
#  '/m/0f6cl2',
#  '/m/0dpl44',
#  '/m/043kzcr',
#  '/m/07z1_q',
#  '/m/04kr63w',
#  '/m/04gf49c',
#  '/m/01x209s',
#  '/m/03kx49',
#  '/m/02py8_w',
#  '/m/05zdk2',
#  '/m/07ghq',
#  '/m/02x0gx',
#  '/m/06mnps',
#  '/m/04lgq',
#  '/m/0355dz',
#  '/m/0d063v',
#  '/m/016ks_',
#  '/m/04rvy8',
#  '/m/06vbd',
#  '/m/0lzb8',
#  '/m/02pbrn',
#  '/m/02cbhg',
#  '/m/045zr',
#  '/m/0fr7nt',
#  '/m/03n785',
#  '/m/059j2',
#  '/m/03q5dr',
#  '/m/03rz2b',
#  '/m/06c62',
#  '/m/020trj',
#  '/m/049l7',
#  '/m/03swmf',
#  '/m/0kzcv',
#  '/m/01k8rb',
#  '/m/0bz6l9',
#  '/m/06frc',
#  '/m/016z68',
#  '/m/03z_g7',
#  '/m/028qdb',
#  '/m/013w2r',
#  '/m/04zyhx',
#  '/m/06whf',
#  '/m/07s95_l',
#  '/m/08_yl1',
#  '/m/01wb7',
#  '/m/0ny75',
#  '/m/0j0k',
#  '/m/0bqytm',
#  '/m/0mcl0',
#  '/m/01k5zk',
#  '/m/05nw9m',
#  '/m/01p1z_',
#  '/m/01rdm0',
#  '/m/012s1d',
#  '/m/04fgkf_',
#  '/m/03rbj2',
#  '/m/09wz9',
#  '/m/0bzjf',
#  '/m/03hdz8',
#  '/m/01rgr',
#  '/m/0h1sg',
#  '/m/031zkw',
#  '/m/01tnbn',
#  '/m/036hnm',
#  '/m/042z_g',
#  '/m/03dq9',
#  '/m/053y0s',
#  '/m/01p5yn',
#  '/m/030155',
#  '/m/039g82',
#  '/m/0235l',
#  '/m/0dj7p',
#  '/m/03b_fm5',
#  '/m/05j82v',
#  '/m/05b_gq',
#  '/m/03_3d',
#  '/m/0d05w3',
#  '/m/04znsy',
#  '/m/026r8q',
#  '/m/0b_6x2',
#  '/m/02633g',
#  '/m/03hl6lc',
#  '/m/01gf5h',
#  '/m/013tcv',
#  '/m/01cf93',
#  '/m/05njyy',
#  '/m/0126t5',
#  '/m/03b78r',
#  '/m/0894_x',
#  '/m/04cxw5b',
#  '/m/0qr4n',
#  '/m/05f2jk',
#  '/m/05r3qc',
#  '/m/03bzyn4',
#  '/m/013m_x',
#  '/m/01dyvs',
#  '/m/050sw4',
#  '/m/0flbm',
#  '/m/09k0f',
#  '/m/02wrhj',
#  '/m/031ldd',
#  '/m/0m_v0',
#  '/m/05xf75',
#  '/m/07j8r',
#  '/m/07y9ts',
#  '/m/0k696',
#  '/m/033jj1',
#  '/m/03n08b',
#  '/m/0j95',
#  '/m/0nqv1',
#  '/m/01wbg84',
#  '/m/024_fw',
#  '/m/0cc5mcj',
#  '/m/03fbb6',
#  '/m/01vv7sc',
#  '/m/01b1mj',
#  '/m/01tpl1p',
#  '/m/02s0pp',
#  '/m/076psv',
#  '/m/09fc83',
#  '/m/0y62n',
#  '/m/07cc8',
#  '/m/07yk1xz',
#  '/m/0b6f8pf',
#  '/m/01z_lv',
#  '/m/038981',
#  '/m/0ctb4g',
#  '/m/05cqhl',
#  '/m/01730d',
#  '/m/07c2yr',
#  '/m/07xpm',
#  '/m/01c40n',
#  '/m/03wbqc4',
#  '/m/0c3zjn7',
#  '/m/0vg8',
#  '/m/01n4w',
#  '/m/0pvms',
#  '/m/0q9sg',
#  '/m/06wpc',
#  '/m/063k3h',
#  '/m/01243b',
#  '/m/027l0b',
#  '/m/036qs_',
#  '/m/0d22f',
#  '/m/03mg3l',
#  '/m/027r7k',
#  '/m/04kd5d',
#  '/m/0234pg',
#  '/m/0cg39k',
#  '/m/02lfwp',
#  '/m/0dt49',
#  '/m/01s3vk',
#  '/m/045nc5',
#  '/m/0gfmc_',
#  '/m/05b7q',
#  '/m/02779r4',
#  '/m/03_80b',
#  '/m/040whs',
#  '/m/0dhd5',
#  '/m/08r98b',
#  '/m/02x17c2',
#  '/m/0841zn',
#  '/m/06fp11',
#  '/m/0dcp_',
#  '/m/014knw',
#  '/m/01wj18h',
#  '/m/02d49z',
#  '/m/02d003',
#  '/m/03ly1b',
#  '/m/07z6xs',
#  '/m/02xx5',
#  '/m/0n5by',
#  '/m/02pv_d',
#  '/m/01pm0_',
#  '/m/0c5qvw',
#  '/m/01l63',
#  '/m/0143wl',
#  '/m/0164v',
#  '/m/03fpg',
#  '/m/0cdf37',
#  '/m/03mcwq3',
#  '/m/09fqd3',
#  '/m/05b5_tj',
#  '/m/019z2l',
#  '/m/01wqg8',
#  '/m/0d6n1',
#  '/m/01t9_0',
#  '/m/0kt_4',
#  '/m/014bpd',
#  '/m/0nv5y',
#  '/m/01nhkxp',
#  '/m/0kqj1',
#  '/m/07nqn',
#  '/m/0hskw',
#  '/m/0hz6mv2',
#  '/m/0mgkg',
#  '/m/01w40h',
#  '/m/032r4n',
#  '/m/060m4',
#  '/m/0126rp',
#  '/m/04tr1',
#  '/m/01lvrm',
#  '/m/01wg3q',
#  '/m/0fhp9',
#  '/m/018l5l',
#  '/m/02y5kn',
#  '/m/02sh8y',
#  '/m/0d2by',
#  '/m/01vsy7t',
#  '/m/0dt39',
#  '/m/078g3l',
#  '/m/0cq8qq',
#  '/m/04mp9q',
#  '/m/0jbk9',
#  '/m/01ddth',
#  '/m/0k3nk',
#  '/m/03b3j',
#  '/m/02swsm',
#  '/m/09wnnb',
#  '/m/03vhvp',
#  '/m/070zc',
#  '/m/0308kx',
#  '/m/021_z5',
#  '/m/061681',
#  '/m/03td5v',
#  '/m/01rk91',
#  '/m/0fbq2n',
#  '/m/0gj9qxr',
#  '/m/0chhs',
#  '/m/01vxxb',
#  '/m/0fc9js',
#  '/m/0xpq9',
#  '/m/01sbhvd',
#  '/m/01gb_p',
#  '/m/07sbk',
#  '/m/03fw4y',
#  '/m/01wkmgb',
#  '/m/011k11',
#  '/m/0hrcs29',
#  '/m/0dr_4',
#  '/m/01j_5k',
#  '/m/045xx',
#  '/m/05bnq8',
#  '/m/01pd60',
#  '/m/05511w',
#  '/m/03k50',
#  '/m/02w4fkq',
#  '/m/015_1q',
#  '/m/013h1c',
#  '/m/0515zg',
#  '/m/04z1v0',
#  '/m/052hl',
#  '/m/02mxbd',
#  '/m/0fbtbt',
#  '/m/01wv9p',
#  '/m/02ptczs',
#  '/m/03rl84',
#  '/m/05mxw33',
#  '/m/0b6l1st',
#  '/m/05k2s_',
#  '/m/098s2w',
#  '/m/0fdtd7',
#  '/m/03f2_rc',
#  '/m/0412f5y',
#  '/m/08phg9',
#  '/m/02q_cc',
#  '/m/05vzw3',
#  '/m/01sb5r',
#  '/m/02q3fdr',
#  '/m/0ftlkg',
#  '/m/02b0_m',
#  '/m/015hr',
#  '/m/0cmt6q',
#  '/m/02fybl',
#  '/m/0150n',
#  '/m/06pjs',
#  '/m/03m79j_',
#  '/m/0lz8d',
#  '/m/04dn71w',
#  '/m/02sn34',
#  '/m/025ttz4',
#  '/m/026rsl9',
#  '/m/01nzmp',
#  '/m/0121sr',
#  '/m/01wbsdz',
#  '/m/0n23n',
#  '/m/083p7',
#  '/m/0nk95',
#  '/m/01kf5lf',
#  '/m/01w4dy',
#  '/m/09mq4m',
#  '/m/01mf0',
#  '/m/086h6p',
#  '/m/054lpb6',
#  '/m/02b149',
#  '/m/01fx5l',
#  '/m/053rd',
#  '/m/0853g',
#  '/m/050r1z',
#  '/m/02r6c_',
#  '/m/07db6x',
#  '/m/070ny',
#  '/m/0b_6lb',
#  '/m/02qyntr',
#  '/m/04xhwn',
#  '/m/05krk',
#  ...]

# %%
model.dict_id2rel
# Out:
# ['/government/politician/government_positions_held./government/government_position_held/basic_title',
#  '/award/award_nominee/award_nominations./award/award_nomination/award',
#  '/sports/sports_team/roster./american_football/football_roster_position/position',
#  '/sports/sports_team/roster./basketball/basketball_roster_position/position',
#  '/broadcast/content/artist',
#  '/base/biblioness/bibs_location/country',
#  '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#  '/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team',
#  '/user/alexander/philosophy/philosopher/interests',
#  '/baseball/baseball_team/team_stats./baseball/baseball_team_stats/season',
#  '/base/biblioness/bibs_location/state',
#  '/influence/influence_node/peers./influence/peer_relationship/peers',
#  '/award/award_winning_work/awards_won./award/award_honor/award',
#  '/music/artist/track_contributions./music/track_contribution/role',
#  '/sports/sports_team/colors',
#  '/education/educational_degree/people_with_this_degree./education/education/major_field_of_study',
#  '/government/governmental_body/members./government/government_position_held/legislative_sessions',
#  '/film/film/film_format',
#  '/music/genre/artists',
#  '/location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division',
#  '/film/film/costume_design_by',
#  '/sports/sports_position/players./sports/sports_team_roster/team',
#  '/location/location/contains',
#  '/film/film_set_designer/film_sets_designed',
#  '/tv/tv_network/programs./tv/tv_network_duration/program',
#  '/location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency',
#  '/music/instrument/instrumentalists',
#  '/sports/sport/pro_athletes./sports/pro_sports_played/athlete',
#  '/people/person/profession',
#  '/government/legislative_session/members./government/government_position_held/district_represented',
#  '/award/award_nominee/award_nominations./award/award_nomination/nominated_for',
#  '/education/university/fraternities_and_sororities',
#  '/music/instrument/family',
#  '/music/record_label/artist',
#  '/business/business_operation/operating_income./measurement_unit/dated_money_value/currency',
#  '/people/deceased_person/place_of_burial',
#  '/base/popstra/celebrity/canoodled./base/popstra/canoodled/participant',
#  '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#  '/government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office',
#  '/tv/tv_program/genre',
#  '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#  '/film/film/music',
#  '/organization/organization/headquarters./location/mailing_address/country',
#  '/military/military_conflict/combatants./military/military_combatant_group/combatants',
#  '/education/educational_institution/students_graduates./education/education/student',
#  '/award/award_winner/awards_won./award/award_honor/award_winner',
#  '/music/group_member/membership./music/group_membership/role',
#  '/media_common/netflix_genre/titles',
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location',
#  '/music/performance_role/guest_performances./music/recording_contribution/performance_role',
#  '/organization/organization/child./organization/organization_relationship/child',
#  '/dataworld/gardening_hint/split_to',
#  '/award/award_ceremony/awards_presented./award/award_honor/honored_for',
#  '/base/americancomedy/celebrity_impressionist/celebrities_impersonated',
#  '/influence/influence_node/influenced_by',
#  '/tv/tv_program/languages',
#  '/travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation',
#  '/time/event/locations',
#  '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics',
#  '/food/food/nutrients./food/nutrition_fact/nutrient',
#  '/celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity',
#  '/ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position',
#  '/base/popstra/celebrity/friendship./base/popstra/friendship/participant',
#  '/music/performance_role/track_performances./music/track_contribution/role',
#  '/people/ethnicity/people',
#  '/film/film/cinematography',
#  '/people/person/places_lived./people/place_lived/location',
#  '/film/film/featured_film_locations',
#  '/sports/sports_league/teams./sports/sports_league_participation/team',
#  '/tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program',
#  '/language/human_language/countries_spoken_in',
#  '/organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency',
#  '/medicine/disease/notable_people_with_this_condition',
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category',
#  '/tv/tv_program/regular_cast./tv/regular_tv_appearance/actor',
#  '/film/film/prequel',
#  '/film/actor/film./film/performance/film',
#  '/location/location/adjoin_s./location/adjoining_relationship/adjoins',
#  '/american_football/football_team/current_roster./sports/sports_team_roster/position',
#  '/business/business_operation/assets./measurement_unit/dated_money_value/currency',
#  '/education/university/domestic_tuition./measurement_unit/dated_money_value/currency',
#  '/location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency',
#  '/film/film/written_by',
#  '/people/person/sibling_s./people/sibling_relationship/sibling',
#  '/film/film/runtime./film/film_cut/film_release_region',
#  '/celebrities/celebrity/celebrity_friends./celebrities/friendship/friend',
#  '/education/educational_degree/people_with_this_degree./education/education/institution',
#  '/film/film/personal_appearances./film/personal_film_appearance/person',
#  '/people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony',
#  '/education/educational_institution/school_type',
#  '/tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program',
#  '/location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source',
#  '/organization/organization/headquarters./location/mailing_address/citytown',
#  '/film/film/story_by',
#  '/organization/role/leaders./organization/leadership/organization',
#  '/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed',
#  '/people/person/employment_history./business/employment_tenure/company',
#  '/government/political_party/politicians_in_this_party./government/political_party_tenure/politician',
#  '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language',
#  '/film/film/produced_by',
#  '/sports/sports_team/sport',
#  '/organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency',
#  '/education/educational_degree/people_with_this_degree./education/education/student',
#  '/award/award_category/winners./award/award_honor/award_winner',
#  '/government/legislative_session/members./government/government_position_held/legislative_sessions',
#  '/sports/sports_league_draft/picks./sports/sports_league_draft_pick/school',
#  '/user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy',
#  '/location/us_county/county_seat',
#  '/film/film/film_art_direction_by',
#  '/medicine/disease/risk_factors',
#  '/education/educational_institution_campus/educational_institution',
#  '/people/person/gender',
#  '/film/film_subject/films',
#  '/award/award_winning_work/awards_won./award/award_honor/honored_for',
#  '/award/award_category/winners./award/award_honor/ceremony',
#  '/people/person/spouse_s./people/marriage/spouse',
#  '/tv/tv_program/program_creator',
#  '/user/jg/default_domain/olympic_games/sports',
#  '/film/film/estimated_budget./measurement_unit/dated_money_value/currency',
#  '/olympics/olympic_games/participating_countries',
#  '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft',
#  '/location/administrative_division/country',
#  '/sports/sports_position/players./american_football/football_historical_roster_position/position_s',
#  '/people/person/spouse_s./people/marriage/location_of_ceremony',
#  '/base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months',
#  '/film/film/release_date_s./film/film_regional_release_date/film_regional_debut_venue',
#  '/film/film/language',
#  '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency',
#  '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school',
#  '/education/educational_institution/colors',
#  '/base/aareas/schema/administrative_area/administrative_parent',
#  '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#  '/film/film/genre',
#  '/base/popstra/celebrity/dated./base/popstra/dated/participant',
#  '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#  '/film/film/country',
#  '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics',
#  '/base/popstra/celebrity/breakup./base/popstra/breakup/participant',
#  '/tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type',
#  '/film/film/executive_produced_by',
#  '/military/military_combatant/military_conflicts./military/military_combatant_group/combatants',
#  '/people/person/nationality',
#  '/award/award_category/disciplines_or_subjects',
#  '/people/ethnicity/geographic_distribution',
#  '/music/artist/origin',
#  '/location/hud_county_place/county',
#  '/location/country/second_level_divisions',
#  '/education/university/local_tuition./measurement_unit/dated_money_value/currency',
#  '/location/country/official_language',
#  '/film/special_film_performance_type/film_performance_type./film/performance/film',
#  '/film/actor/film./film/performance/special_performance_type',
#  '/music/performance_role/regular_performances./music/group_membership/role',
#  '/sports/sports_team/roster./american_football/football_historical_roster_position/position_s',
#  '/location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency',
#  '/award/award_winning_work/awards_won./award/award_honor/award_winner',
#  '/business/business_operation/revenue./measurement_unit/dated_money_value/currency',
#  '/location/location/time_zones',
#  '/music/group_member/membership./music/group_membership/group',
#  '/film/film/film_production_design_by',
#  '/education/field_of_study/students_majoring./education/education/major_field_of_study',
#  '/film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance',
#  '/location/statistical_region/places_exported_to./location/imports_and_exports/exported_to',
#  '/location/location/partially_contains',
#  '/sports/sports_position/players./sports/sports_team_roster/position',
#  '/organization/organization/place_founded',
#  '/music/genre/parent_genre',
#  '/base/culturalevent/event/entity_involved',
#  '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics',
#  '/location/statistical_region/religions./location/religion_percentage/religion',
#  '/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer',
#  '/tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person',
#  '/time/event/instance_of_recurring_event',
#  '/award/ranked_item/appears_in_ranked_lists./award/ranking/list',
#  '/travel/travel_destination/climate./travel/travel_destination_monthly_climate/month',
#  '/people/profession/specialization_of',
#  '/olympics/olympic_games/sports',
#  '/sports/pro_athlete/teams./sports/sports_team_roster/team',
#  '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#  '/people/cause_of_death/people',
#  '/olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal',
#  '/location/hud_county_place/place',
#  '/sports/sports_team_location/teams',
#  '/base/locations/continents/countries_within',
#  '/film/director/film',
#  '/sports/sports_team/roster./baseball/baseball_roster_position/position',
#  '/award/award_nominated_work/award_nominations./award/award_nomination/nominated_for',
#  '/people/deceased_person/place_of_death',
#  '/people/person/languages',
#  '/people/ethnicity/languages_spoken',
#  '/business/job_title/people_with_this_title./business/employment_tenure/company',
#  '/tv/tv_program/country_of_origin',
#  '/people/person/religion',
#  '/base/aareas/schema/administrative_area/administrative_area_type',
#  '/location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency',
#  '/base/eating/practicer_of_diet/diet',
#  '/location/administrative_division/first_level_division_of',
#  '/award/award_category/nominees./award/award_nomination/nominated_for',
#  '/film/film/film_festivals',
#  '/organization/organization_member/member_of./organization/organization_membership/organization',
#  '/film/film/other_crew./film/film_crew_gig/crewmember',
#  '/film/film/production_companies',
#  '/base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members',
#  '/organization/organization/headquarters./location/mailing_address/state_province_region',
#  '/location/country/capital',
#  '/education/university/international_tuition./measurement_unit/dated_money_value/currency',
#  '/government/politician/government_positions_held./government/government_position_held/legislative_sessions',
#  '/government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office',
#  '/location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency',
#  '/education/field_of_study/students_majoring./education/education/student',
#  '/people/person/place_of_birth',
#  '/organization/organization_founder/organizations_founded',
#  '/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club',
#  '/tv/tv_producer/programs_produced./tv/tv_producer_term/program',
#  '/film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium',
#  '/education/educational_institution/campuses',
#  '/award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee',
#  '/business/business_operation/industry',
#  '/film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium',
#  '/soccer/football_team/current_roster./sports/sports_team_roster/position',
#  '/tv/tv_program/tv_producer./tv/tv_producer_term/producer_type',
#  '/film/film/edited_by',
#  '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#  '/user/ktrueman/default_domain/international_organization/member_states',
#  '/medicine/symptom/symptom_of',
#  '/base/aareas/schema/administrative_area/capital',
#  '/location/country/form_of_government',
#  '/award/award_category/category_of',
#  '/soccer/football_team/current_roster./soccer/football_roster_position/position',
#  '/common/topic/webpage./common/webpage/category',
#  '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal',
#  '/film/film/distributors./film/film_film_distributor_relationship/region',
#  '/people/person/spouse_s./people/marriage/type_of_union',
#  '/music/performance_role/regular_performances./music/group_membership/group',
#  '/soccer/football_player/current_team./sports/sports_team_roster/team',
#  '/film/film/dubbing_performances./film/dubbing_performance/actor',
#  '/film/actor/dubbing_performances./film/dubbing_performance/language',
#  '/music/artist/contribution./music/recording_contribution/performance_role']
